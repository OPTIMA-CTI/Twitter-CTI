# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
misp_df = pd.read_csv(r'/content/drive/MyDrive/Twitter_Work_Code/TIP/MISP/misp_output.csv',encoding='utf-8', low_memory=False)

# %%
misp_df
# Out:
#                       tweet_date        account  ioc_type  \
# 0                     tweet_date        account  ioc_type
# 1                     tweet_date        account  ioc_type
# 2      2021-01-01 00:09:03+00:00  MalwarePatrol       url
# 3      2021-01-01 00:09:03+00:00  MalwarePatrol       url
# 4      2021-01-01 00:09:03+00:00  MalwarePatrol    domain
# ...                          ...            ...       ...
# 90988  2021-07-31 21:01:16+00:00  ShoestringSoc        ip
# 90989  2021-07-31 21:19:38+00:00       ecarlesi       url
# 90990  2021-07-31 21:25:08+00:00       ecarlesi       url
# 90991  2021-07-31 22:56:45+00:00    phishunt_io        ip
# 90992  2021-07-31 22:56:45+00:00    phishunt_io    domain
#
#                                                ioc_value  type_of_attack  \
# 0                                              ioc_value  type_of_attack
# 1                                              ioc_value  type_of_attack
# ...

# %%
misp_df=misp_df[misp_df['misp_status'] =='Not Found']

# %%
url_df=misp_df[misp_df['ioc_type'] =='url']

# %%
url_df = url_df['ioc_value']

# %%
url_df[1:100]
# Out:
#                     tweet_date     account ioc_type  \
# 6    2021-01-01 00:26:26+00:00  PhishStats      url
# 7    2021-01-01 00:26:26+00:00  PhishStats      url
# 8    2021-01-01 00:26:26+00:00  PhishStats      url
# 10   2021-01-01 00:31:00+00:00    ecarlesi      url
# 11   2021-01-01 00:31:25+00:00    ecarlesi      url
# ..                         ...         ...      ...
# 153  2021-01-01 20:48:19+00:00    ecarlesi      url
# 154  2021-01-01 21:13:50+00:00  PhishStats      url
# 155  2021-01-01 22:41:23+00:00    jaalmain      url
# 156  2021-01-01 22:41:23+00:00    jaalmain      url
# 157  2021-01-01 23:24:46+00:00   romonlyht      url
#
#                                              ioc_value  \
# 6                  http://departmen-advant-page.my.id/
# 7                              https://t.co/o6baJynzrX
# 8                               http://205.144.171.153
# 10   http://teamfrenette.com/wp-content/plugins/ele...
# 11   http://teamfrenette.com/wp-content/plugins/ele...
# ...

# %%
domain_df=misp_df[misp_df['ioc_type'] =='domain']

# %%
domain_df[100:200]
# Out:
#                      tweet_date        account ioc_type  \
# 962   2021-01-05 20:10:33+00:00      IronNetTR   domain
# 963   2021-01-05 20:10:33+00:00      IronNetTR   domain
# 990   2021-01-06 00:02:24+00:00      romonlyht   domain
# 993   2021-01-06 00:09:03+00:00  MalwarePatrol   domain
# 996   2021-01-06 00:29:03+00:00   oneleggoalie   domain
# ...                         ...            ...      ...
# 2162  2021-01-08 07:01:48+00:00     TeamDreier   domain
# 2187  2021-01-08 07:36:43+00:00        yvesago   domain
# 2188  2021-01-08 07:36:43+00:00        yvesago   domain
# 2189  2021-01-08 07:36:43+00:00        yvesago   domain
# 2191  2021-01-08 07:44:40+00:00  papa_anniekey   domain
#
#                                ioc_value           type_of_attack  \
# 962             online-securepayment.com  ['opendir', 'phishing']
# 963           authenticate-mydetails.com  ['opendir', 'phishing']
# 990                novayamhealthcare.com             ['phishing']
# ...
