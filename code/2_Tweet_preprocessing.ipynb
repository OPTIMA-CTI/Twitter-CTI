# %%
import pandas as pd
import re
import warnings
warnings.filterwarnings("ignore")
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Merge/Tweets/FinalTweet.csv')  #read csv file

# %%
df
# Out:
#         Unnamed: 0     Author ID        User Name  \
# 0                0  1.131854e+18   cybersec_feeds
# 1                1  2.217691e+09     Anne_Orichan
# 2                2  1.255183e+18  InbraakveiligBE
# 3                3  1.363657e+08    daikon__orosi
# 4                4  1.003694e+18  JessiCartoons11
# ...            ...           ...              ...
# 2414659      59043  7.101237e+17         sectest9
# 2414660      59044  1.142424e+18  CyberSecurityN8
# 2414661      59045  5.693841e+08        velez1066
# 2414662      59046  2.918316e+08    Paula_Piccard
# 2414663      59047  4.501058e+08       ItsTrigger
#
#                               Screen Name      Tweet ID  \
# 0                     Cyber Security Feed  1.421622e+18
# 1                                 orichan  1.421622e+18
# 2                     Inbraakveilig Group  1.421621e+18
# 3        大根おろし Let's get ready to rumble!  1.421621e+18
# 4                      Jessica Spencer 🎙🎨  1.421621e+18
# ...

# %%
print(df.shape) #print original datframe shape
# Out:
# (2414664, 28)

# %%
df=df[df['Language'] =='en' ]  #exclude non english tweets

# %%
print(df.shape)  # prin the shape of the english tweets
# Out:
# (1390185, 28)

# %%
df=df[df['Type of Referenced Tweets'] !='retweeted' ] #exclude retweets from tweets

# %%
print(df.shape)
# Out:
# (445049, 28)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Author ID', 'User Name', 'Screen Name', 'Tweet ID',
#        'Created At', 'Text', 'Like Count', 'Quote Count', 'Reply Count',
#        'Retweet Count', 'Entities', 'Expanded URL', 'Hashtag',
#        'Mentioned Username', 'Annotated Entity', 'Annotation Probability',
#        'Annotation Type', 'Conversation ID', 'Referenced Tweets',
#        'ID of Referenced Tweets', 'Type of Referenced Tweets', 'Attachments',
#        'Location tagged by the user', 'Language', 'Sensitive URL',
#        'Reply Settings', 'Source'],
#       dtype='object')

# %%
df=df.drop(['Unnamed: 0', 'Author ID', 'User Name', 'Screen Name', 'Tweet ID',
       'Created At', 'Text', 'Like Count', 'Quote Count', 'Reply Count',
       'Retweet Count', 'Entities', 'Expanded URL', 'Hashtag',
       'Mentioned Username', 'Conversation ID', 'Referenced Tweets',
       'ID of Referenced Tweets', 'Type of Referenced Tweets', 'Attachments',
       'Location tagged by the user', 'Language', 'Sensitive URL',
       'Reply Settings', 'Source'],axis=1)

# %%
df
# Out:
#                 Annotated Entity Annotation Probability   Annotation Type
# 36                           NaN                    NaN               NaN
# 38                           NaN                    NaN               NaN
# 46                    ['Canada']               [0.9869]         ['Place']
# 48                           NaN                    NaN               NaN
# 50                           NaN                    NaN               NaN
# ...                          ...                    ...               ...
# 2414650  ['The An0nym0us Truth']               [0.4339]         ['Other']
# 2414654                      NaN                    NaN               NaN
# 2414661                      NaN                    NaN               NaN
# 2414662            ['Microsoft']               [0.6101]  ['Organization']
# 2414663                      NaN                    NaN               NaN
#
# [445049 rows x 3 columns]

# %%
df=df.sort_values(['Created At'])  #sort by created date

# %%
df
# Out:
#         Unnamed: 0     Author ID       User Name                Screen Name  \
# 2414663      59047  4.501058e+08      ItsTrigger                    Trigger
# 2414662      59046  2.918316e+08   Paula_Piccard              Paula Piccard
# 2414661      59045  5.693841e+08       velez1066                Jorge Velez
# 2414654      59038  9.154360e+17  MoustachedTrex                     Johnny
# 2414650      59034  1.059414e+09      An0n_Truth                  Anonymous
# ...            ...           ...             ...                        ...
# 50              50  1.384262e+18    hankobaggins                  hanko.sol
# 48              48  9.503332e+17      HeliosCert                HELIOS CERT
# 46              46  2.469117e+08         PMProuk        Jason Normanton 🤍💙💛
# 38              38  9.202597e+17     cyberinform           Jose Lagdameo Jr
# 36              36  1.491098e+08      CyberSecDN  Cyber Security Daily News
#
#              Tweet ID                 Created At  \
# ...

# %%
# Using DataFrame.drop_duplicates() to keep first duplicate row
df.drop_duplicates(subset ="Text",
                     keep = 'first', inplace = True)

# %%
df
# Out:
#         Unnamed: 0     Author ID       User Name                Screen Name  \
# 2414663      59047  4.501058e+08      ItsTrigger                    Trigger
# 2414662      59046  2.918316e+08   Paula_Piccard              Paula Piccard
# 2414661      59045  5.693841e+08       velez1066                Jorge Velez
# 2414654      59038  9.154360e+17  MoustachedTrex                     Johnny
# 2414650      59034  1.059414e+09      An0n_Truth                  Anonymous
# ...            ...           ...             ...                        ...
# 50              50  1.384262e+18    hankobaggins                  hanko.sol
# 48              48  9.503332e+17      HeliosCert                HELIOS CERT
# 46              46  2.469117e+08         PMProuk        Jason Normanton 🤍💙💛
# 38              38  9.202597e+17     cyberinform           Jose Lagdameo Jr
# 36              36  1.491098e+08      CyberSecDN  Cyber Security Daily News
#
#              Tweet ID                 Created At  \
# ...

# %%
print(df.shape)
# Out:
# (430187, 28)

# %%
df.to_csv('/content/drive/MyDrive/output/Final_Unique_Tweets.csv')
