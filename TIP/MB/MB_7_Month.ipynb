# %%
import pandas as pd
from ISO3166 import ISO3166
from datetime import datetime
from concurrent.futures import ThreadPoolExecutor
import time
import requests

# to calculate analysis time
start_time = time.time()

# Field names for the dataset
fields_name = ['tweet_date', 'account', 'ioc_type', 'ioc_value', 'type_of_attack', 'tweet_url', 'text','mb_status', 'mb_first_seen',
               'mb_last_seen', 'signature', 'file_type', 'reporter', 'origin_country', 'first_report', 'time_difference', 'time_difference(sec)', 'reference']


# To read saved local copy of database
df = pd.read_csv('/content/drive/MyDrive/Twitter_Work_Code/TIP/MB/mb_output_preprocessed_11_7_2022.csv',names=fields_name, encoding='utf-8', low_memory=False,lineterminator='\n')
# Filtering hashes
"""df = df[(df['ioc_type'] == 'hash')].reset_index(drop=True)
df=df[1:20]"""

# To collect the values from malwarebazar and update the dataframe
def report(index):
    ioc_type=df.loc[index,'ioc_type']
    if ioc_type not in ['hash']:
      return
    ioc = (df.loc[index,'ioc_value']).strip()

    # To get the api response   
    while True:
        try:
            response = requests.post("https://mb-api.abuse.ch/api/v1/",{'query':'get_info','hash':ioc})
            break
        except Exception as e:
            print({'Error':str(e)})

    response=response.json()
    print(response['query_status'])

    # Writing the data to dataframe
    if response['query_status'] == 'hash_not_found':
        df.loc[index, 'mb_status'] = "Not Found"
    else:
        df.loc[index, 'mb_status'] = "Malicious"
        print(df.loc[index, 'mb_status'])
        print(response['data'][0]['first_seen'])
        print(type(response['data'][0]['first_seen']))
        source_date = df.loc[index, 'tweet_date']
        tweet_date=source_date[:19]
        print('tweet type',type(tweet_date))
        first_seen_date = response['data'][0]['first_seen']
        print('tweet',tweet_date)
        print('mbdate',first_seen_date)
        tweet_date = datetime.strptime(tweet_date,'%Y-%m-%d %H:%M:%S')
        print('tweet type',type(tweet_date))
        first_seen_date = datetime.strptime(first_seen_date,'%Y-%m-%d %H:%M:%S')
        print("fdhhhhhhh",type(first_seen_date))
        if first_seen_date < tweet_date:
            df.loc[index, "first_report"] = "Malware Bazaar"
            time_diff = tweet_date-first_seen_date
            print("mb")
        else:            
            df.loc[index, 'first_report'] = "Twitter"
            time_diff = first_seen_date-tweet_date
            print("twitter")
        print(time_diff)
        print(df.loc[index, 'first_report'])
        df.loc[index, "time_difference"] = time_diff
        df.loc[index, "time_difference(sec)"] = time_diff.total_seconds()
        df.loc[index, "mb_first_seen"] = response['data'][0]['first_seen']
        df.loc[index, "mb_last_seen"] = response['data'][0]['last_seen']
        df.loc[index, "signature"] = response['data'][0]['signature']
        df.loc[index, 'file_type'] = response['data'][0]['file_type']
        df.loc[index, 'reporter'] = response['data'][0]['reporter']
        df.loc[index, 'origin_country'] = ISO3166[response['data'][0]['origin_country']]

        df.loc[index, 'reference'] = "https://bazaar.abuse.ch/sample/" + response['data'][0]['sha256_hash']
        print("test")
        print("Differebce",df.loc[index, 'time_difference'])
        print("test_sec", time_diff.total_seconds())
        print(df.loc[index, 'time_difference(sec)'])
    print(index, ioc, df.loc[index, "mb_status"])
# To run the queries as multithreaded for faster execution rate
with ThreadPoolExecutor(max_workers=1) as executor:
    executor.map(report, range(1,20))
    executor.shutdown(wait=True)

# Writeout the database as csv for storage
df.to_csv('/content/drive/MyDrive/Twitter_Work_Code/TIP/MB/MB_Output.csv', na_rep='', index=None,errors='ignore')

print(f'\nTime : {time.time() - start_time : .2f}')
# Out:
# hash_not_found
# 1 3f54d9331db97a9e41acf56ab52f0c8a2702b4eca5233cb5e2056080fcf47cd4 Not Found
# hash_not_found
# 2 a1131f1e5dcdd983fa79308ecd868165a133f56708fcb0a9e1723459b9136c3b Not Found
# hash_not_found
# 3 a5bfc9e07964f8dddeb95fc584cd965d Not Found
# hash_not_found
# 4 2ec0540b5f51d63864bda26ab5f54b1fed06eab5f42c60b7c4a14152ddb456bf Not Found
# hash_not_found
# 5 35cafdb930cf6cd24b65e5e639c3253c Not Found
# hash_not_found
# 6 c136b1467d669a725478a6110ebaaab3cb88a3d389dfa688e06173c066b76fcf Not Found
# ok
# Malicious
# 2022-07-20 05:56:18
# <class 'str'>
# tweet type <class 'str'>
# tweet 2021-01-02 06:10:02
# mbdate 2022-07-20 05:56:18
# tweet type <class 'datetime.datetime'>
# fdhhhhhhh <class 'datetime.datetime'>
# twitter
# 563 days, 23:46:16
# Twitter
# hash_not_found
# 8 da8591758cf7f86fd5bafacb7ce10c2f0b282aa8793227ab0381e13e1273b70f Not Found
# hash_not_found
# 9 545360f94e9d827e1757e8d4768c3b652a55061216a2fe0894043e6850467eea Not Found
# hash_not_found
# 10 6ea9ab1baa0efb9e19094440c317e21b Not Found
# hash_not_found
# 11 fbd7939d674997cdb4692d34de8633c4 Not Found
# hash_not_found
# 12 84a7379b40b4cbc46df78255f20cd5f38ad217869d10d6164d9220a6b512f9f3 Not Found
# hash_not_found
# 13 be89ec93bf8d8d01fd2a88b7ee993d1cc8e57560ae84204ce7b008a8a9a09507 Not Found
# hash_not_found
# 14 b6d767d2f8ed5d21a44b0e5886680cb9 Not Found
# hash_not_found
# 15 46ac9367b9244bf24bb1029c78ce05da Not Found
# hash_not_found
# 16 f7d5730417f81d7ce6f8b231dbd333e4 Not Found
# hash_not_found
# 17 44a78e41f2d6dbd375d286ccdc5e0e16 Not Found
# hash_not_found
# 18 5aec6e6089d7281fe47ea64d1685e420f6cd99828137dbe8c6674c90a65dc52a Not Found
# hash_not_found
# 19 9348ff35903052b6874508e0fa116dacc4dca5b0a60710a6084c3ac5f01ae85f Not Found
#
# Time :  7.77

# %%
df
# Out:
#                      tweet_date        account  ioc_type  \
# 0                    tweet_date        account  ioc_type
# 1     2021-01-01 05:53:40+00:00        ReBensk      hash
# 2     2021-01-01 08:20:02+00:00     HeliosCert      hash
# 3     2021-01-01 08:56:21+00:00       ecarlesi      hash
# 4     2021-01-01 11:35:02+00:00     HeliosCert      hash
# ...                         ...            ...       ...
# 4541  2021-07-31 12:30:02+00:00     HeliosCert      hash
# 4542  2021-07-31 16:58:04+00:00  MalwarePatrol      hash
# 4543  2021-07-31 16:58:04+00:00  MalwarePatrol      hash
# 4544  2021-07-31 17:15:02+00:00     HeliosCert      hash
# 4545  2021-07-31 20:40:02+00:00     HeliosCert      hash
#
#                                               ioc_value  type_of_attack  \
# 0                                             ioc_value  type_of_attack
# 1     3f54d9331db97a9e41acf56ab52f0c8a2702b4eca5233c...     ['malware']
# 2     a1131f1e5dcdd983fa79308ecd868165a133f56708fcb0...     ['malware']
# 3                      a5bfc9e07964f8dddeb95fc584cd965d    ['phishing']
# 4     2ec0540b5f51d63864bda26ab5f54b1fed06eab5f42c60...     ['malware']
# ...                                                 ...             ...
# 4541  02781974804e2467b3900993e48cb5b884bd68f03d0045...     ['malware']
# 4542                   fbe51695e97a45dc61967dc3241a37dc     ['malware']
# 4543           1ed14334b5b71783cd6ec14b8a704fe48e600cf0     ['malware']
# 4544  c359b6169a1e9eeae664a5811ebc8512dd224e6930613b...     ['malware']
# 4545  c234cce33c7388d7e2df001790882689e901e9306bd527...     ['malware']
#
#                    tweet_url  \
# 0                  tweet_url
# 1     1.3448844755246162e+18
# 2     1.3449213105022648e+18
# 3      1.344930451694076e+18
# 4     1.3449703824204186e+18
# ...                      ...
# 4541  1.4214480652617073e+18
# 4542  1.4215155191155302e+18
# 4543  1.4215155191155302e+18
# 4544   1.421519789349118e+18
# 4545  1.4215713774889288e+18
#
#                                                    text  mb_status  \
# 0                                                  text  mb_status
# 1     #Android #Banking #Trojan #Malware\n@malwrhunt...  Not Found
# 2     Sample submitted\n2021-01-01 08:20:02\nDionaea...  Not Found
# 3     Threat on hxxps://check-payeeid[.]com/HSBC/idv...  Not Found
# 4     Sample submitted\n2021-01-01 11:35:01\nURL: ht...  Not Found
# ...                                                 ...        ...
# 4541  Sample submitted\n2021-07-31 12:30:02\nDionaea...      Clean
# 4542  One of the active #malware samples detected on...  Malicious
# 4543  One of the active #malware samples detected on...  Malicious
# 4544  Sample submitted\n2021-07-31 17:15:02\nDionaea...      Clean
# 4545  Sample submitted\n2021-07-31 20:40:02\nDionaea...      Clean
#
#             mb_first_seen         mb_last_seen  signature  file_type  \
# 0           mb_first_seen         mb_last_seen  signature  file_type
# 1                     NaN                  NaN        NaN        NaN
# 2                     NaN                  NaN        NaN        NaN
# 3                     NaN                  NaN        NaN        NaN
# 4                     NaN                  NaN        NaN        NaN
# ...                   ...                  ...        ...        ...
# 4541                  NaN                  NaN        NaN        NaN
# 4542  2021-03-01 23:09:40  2022-03-06 17:31:04        NaN        elf
# 4543  2021-03-01 23:09:40  2022-03-06 17:31:04        NaN        elf
# 4544                  NaN                  NaN        NaN        NaN
# 4545                  NaN                  NaN        NaN        NaN
#
#              reporter  origin_country  first_report  time_difference  \
# 0            reporter  origin_country  first_report  time_difference
# 1                 NaN             NaN           NaN              NaN
# 2                 NaN             NaN           NaN              NaN
# 3                 NaN             NaN           NaN              NaN
# 4                 NaN             NaN           NaN              NaN
# ...               ...             ...           ...              ...
# 4541              NaN             NaN           NaN              NaN
# 4542  realTWISTEDCATS             NaN           NaN              NaN
# 4543  realTWISTEDCATS             NaN           NaN              NaN
# 4544              NaN             NaN           NaN              NaN
# 4545              NaN             NaN           NaN              NaN
#
#       time_difference(sec)  reference
# 0     time_difference(sec)  reference
# 1                      NaN        NaN
# 2                      NaN        NaN
# 3                      NaN        NaN
# 4                      NaN        NaN
# ...                    ...        ...
# 4541                   NaN        NaN
# 4542                   NaN        NaN
# 4543                   NaN        NaN
# 4544                   NaN        NaN
# 4545                   NaN        NaN
#
# [4546 rows x 18 columns]

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Twitter_Work_Code/TIP/MB/mb_output.csv',encoding='utf-8', low_memory=False,lineterminator='\n')
# Filtering hashesv

# %%
df
# Out:
#                       tweet_date        account  ioc_type  \
# 0                     tweet_date        account  ioc_type
# 1      2021-01-01 00:09:03+00:00  MalwarePatrol       url
# 2      2021-01-01 00:09:03+00:00  MalwarePatrol       url
# 3      2021-01-01 00:09:03+00:00  MalwarePatrol    domain
# 4      2021-01-01 00:09:03+00:00  MalwarePatrol    domain
# ...                          ...            ...       ...
# 93790  2021-07-31 21:01:16+00:00  ShoestringSoc        ip
# 93791  2021-07-31 21:19:38+00:00       ecarlesi       url
# 93792  2021-07-31 21:25:08+00:00       ecarlesi       url
# 93793  2021-07-31 22:56:45+00:00    phishunt_io        ip
# 93794  2021-07-31 22:56:45+00:00    phishunt_io    domain
#
#                                                ioc_value  type_of_attack  \
# 0                                              ioc_value  type_of_attack
# 1                               http://dubioustimes.com/    ['phishing']
# 2                                https://t.co/m4mjDMt7az    ['phishing']
# 3                                       dubioustimes.com    ['phishing']
# 4                                                   t.co    ['phishing']
# ...                                                  ...             ...
# 93790                                     197.156.73.150    ['honeypot']
# 93791  http://xmyparcel21-redelivery.com/postoffice/fee/    ['phishing']
# 93792           http://igbusiness-form.com/283772919101/    ['phishing']
# 93793                                      217.160.0.240    ['phishing']
# 93794                            bankofamerica-miami.com    ['phishing']
#
#                     tweet_url  \
# 0                    tweet_id
# 1      1.3447977507481887e+18
# 2      1.3447977507481887e+18
# 3      1.3447977507481887e+18
# 4      1.3447977507481887e+18
# ...                       ...
# 93790  1.4215767218080522e+18
# 93791  1.4215813444679803e+18
# 93792   1.421582728231678e+18
# 93793   1.421605783297413e+18
# 93794   1.421605783297413e+18
#
#                                                     text mb_status  \
# 0                                                   text       NaN
# 1      Another active #Phishing targeting Google Driv...       NaN
# 2      Another active #Phishing targeting Google Driv...       NaN
# 3      Another active #Phishing targeting Google Driv...       NaN
# 4      Another active #Phishing targeting Google Driv...       NaN
# ...                                                  ...       ...
# 93790  New attacker reported:\n\nIP:   197.156.73.150...       NaN
# 93791  Threat on hxxps://xmyparcel21-redelivery[.]com...       NaN
# 93792  Threat on hxxps://igbusiness-form[.]com/283772...       NaN
# 93793  #NewPhishing | #phishing #scam\n\n🌐 /bankofame...       NaN
# 93794  #NewPhishing | #phishing #scam\n\n🌐 /bankofame...       NaN
#
#       mb_first_seen mb_last_seen signature file_type reporter  origin_country  \
# 0               NaN          NaN       NaN       NaN      NaN             NaN
# 1               NaN          NaN       NaN       NaN      NaN             NaN
# 2               NaN          NaN       NaN       NaN      NaN             NaN
# 3               NaN          NaN       NaN       NaN      NaN             NaN
# 4               NaN          NaN       NaN       NaN      NaN             NaN
# ...             ...          ...       ...       ...      ...             ...
# 93790           NaN          NaN       NaN       NaN      NaN             NaN
# 93791           NaN          NaN       NaN       NaN      NaN             NaN
# 93792           NaN          NaN       NaN       NaN      NaN             NaN
# 93793           NaN          NaN       NaN       NaN      NaN             NaN
# 93794           NaN          NaN       NaN       NaN      NaN             NaN
#
#        first_report  time_difference  time_difference(sec)  reference
# 0               NaN              NaN                   NaN        NaN
# 1               NaN              NaN                   NaN        NaN
# 2               NaN              NaN                   NaN        NaN
# 3               NaN              NaN                   NaN        NaN
# 4               NaN              NaN                   NaN        NaN
# ...             ...              ...                   ...        ...
# 93790           NaN              NaN                   NaN        NaN
# 93791           NaN              NaN                   NaN        NaN
# 93792           NaN              NaN                   NaN        NaN
# 93793           NaN              NaN                   NaN        NaN
# 93794           NaN              NaN                   NaN        NaN
#
# [93795 rows x 18 columns]

# %%
mb_df=pd.read_csv("/content/drive/MyDrive/TIP/MB/MB_Output.csv",lineterminator='\n')
mb_df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                        tweet_date         account  ioc_type  \
# 0                      tweet_date         account  ioc_type
# 1       2021-01-01 00:00:02+00:00      ItsTrigger       url
# 2       2021-01-01 00:00:26+00:00   Paula_Piccard       url
# 3       2021-01-01 00:03:25+00:00  MoustachedTrex       url
# 4       2021-01-01 00:06:06+00:00      An0n_Truth       url
# ...                           ...             ...       ...
# 355402  2021-07-31 23:50:21+00:00         PMProuk       url
# 355403  2021-07-31 23:52:04+00:00     cyberinform       url
# 355404  2021-07-31 23:52:04+00:00     cyberinform    domain
# 355405  2021-07-31 23:52:10+00:00      CyberSecDN    domain
# 355406  2021-07-31 23:52:10+00:00      CyberSecDN       url
#
#                                                 ioc_value  \
# 0                                               ioc_value
# 1                       https://pastebin.com/raw/yS4QMNxk
# 2                                  https://zd.net/2WXvcDR
# 3                           https://pastebin.com/Wdgiq6Mm
# 4       https://paper.li/An0n_Truth/1357567312?edition...
# ...                                                   ...
# 355402  https://www.canadianunderwriter.ca/insurance/a...
# 355403                             https://bit.ly/3j7xo6w
# 355404                                             bit.ly
# 355405                         marketresearchtelecast.com
# 355406  https://marketresearchtelecast.com/security-re...
#
#                  type_of_attack            tweet_url  \
# 0                type_of_attack             tweet_id
# 1                            []  1344795482804117504
# 2       ['malware', 'phishing']  1344795582053937153
# 3                            []  1344796334268805125
# 4                   ['malware']  1344797006288584705
# ...                         ...                  ...
# 355402          ['cyberattack']  1421619269947822080
# 355403           ['ransomware']  1421619701889785861
# 355404           ['ransomware']  1421619701889785861
# 355405              ['malware']  1421619729651748865
# 355406              ['malware']  1421619729651748865
#
#                                                      text  mb_status  \
# 0                                                    text        NaN
# 1       2020 was rough for us all. I don't usually wri...        NaN
# 2       SolarWinds hackers accessed Microsoft source c...        NaN
# 3       https://t.co/L4NQPYJ8K7 A list of everything I...        NaN
# 4       The latest The An0nym0us Truth! https://t.co/X...        NaN
# ...                                                   ...        ...
# 355402  As cyberattacks skyrocket, Canada needs to wor...        NaN
# 355403  #Ransomware attacks in #2021 have already surp...        NaN
# 355404  #Ransomware attacks in #2021 have already surp...        NaN
# 355405  Security researcher: Criminals use Discord to ...        NaN
# 355406  Security researcher: Criminals use Discord to ...        NaN
#
#         mb_first_seen  mb_last_seen  signature  file_type  reporter  \
# 0                 NaN           NaN        NaN        NaN       NaN
# 1                 NaN           NaN        NaN        NaN       NaN
# 2                 NaN           NaN        NaN        NaN       NaN
# 3                 NaN           NaN        NaN        NaN       NaN
# 4                 NaN           NaN        NaN        NaN       NaN
# ...               ...           ...        ...        ...       ...
# 355402            NaN           NaN        NaN        NaN       NaN
# 355403            NaN           NaN        NaN        NaN       NaN
# 355404            NaN           NaN        NaN        NaN       NaN
# 355405            NaN           NaN        NaN        NaN       NaN
# 355406            NaN           NaN        NaN        NaN       NaN
#
#         origin_country  first_report  time_difference  time_difference(sec)  \
# 0                  NaN           NaN              NaN                   NaN
# 1                  NaN           NaN              NaN                   NaN
# 2                  NaN           NaN              NaN                   NaN
# 3                  NaN           NaN              NaN                   NaN
# 4                  NaN           NaN              NaN                   NaN
# ...                ...           ...              ...                   ...
# 355402             NaN           NaN              NaN                   NaN
# 355403             NaN           NaN              NaN                   NaN
# 355404             NaN           NaN              NaN                   NaN
# 355405             NaN           NaN              NaN                   NaN
# 355406             NaN           NaN              NaN                   NaN
#
#         reference
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 355402        NaN
# 355403        NaN
# 355404        NaN
# 355405        NaN
# 355406        NaN
#
# [355407 rows x 18 columns]

# %%
df[19230:20000]
# Out:
#                       tweet_date        account ioc_type  \
# 19230  2021-07-22 05:06:38+00:00        bamitav      url
# 19231  2021-07-22 05:06:38+00:00        bamitav   domain
# 19232  2021-07-22 05:05:28+00:00      MoHossain      url
# 19233  2021-07-22 05:04:52+00:00      GrimroPOE      url
# 19234  2021-07-22 05:01:13+00:00  ShoestringSoc       ip
# ...                          ...            ...      ...
# 19995  2021-07-21 17:09:14+00:00     blumirasec      url
# 19996  2021-07-21 17:09:14+00:00     blumirasec   domain
# 19997  2021-07-21 17:09:04+00:00   vigilance_en      url
# 19998  2021-07-21 17:09:04+00:00   vigilance_en      CVE
# 19999  2021-07-21 17:09:01+00:00      Bill4Time      url
#
#                                                ioc_value  \
# 19230  https://www.murfreesboropost.com/news/national...
# 19231                                   murfreesboropost
# 19232  https://www.ft.com/content/76fdac7c-7076-47a4-...
# 19233                      https://pastebin.com/nxRqS0hV
# 19234                                       139.0.102.26
# ...                                                  ...
# 19995  https://www.blumira.com/sam-database-vulnerabi...
# 19996                                            blumira
# 19997  https://vigilance.fr/vulnerability/NVIDIA-Grap...
# 19998                                      CVE-2021-1093
# 19999                               https://fal.cn/3gUEk
#
#                                           type_of_attack            tweet_url  \
# 19230  ['malware', 'ransomware', 'botnet', 'cyberatta...  1418074989840846848
# 19231  ['malware', 'ransomware', 'botnet', 'cyberatta...  1418074989840846848
# 19232                      ['ransomware', 'cyberattack']  1418074693987405827
# 19233                                                 []  1418074545156546560
# 19234                                       ['honeypot']  1418073627308658689
# ...                                                  ...                  ...
# 19995                                            ['cve']  1417894449166888966
# 19996                                            ['cve']  1417894449166888966
# 19997                                            ['cve']  1417894405881663489
# 19998                                            ['cve']  1417894405881663489
# 19999                                    ['cyberattack']  1417894395437797382
#
#                                                     text mb_status  \
# 19230  #US blames #China for hacks, opening new front...       NaN
# 19231  #US blames #China for hacks, opening new front...       NaN
# 19232  Exporting Chinese surveillance: the security r...       NaN
# 19233  @Zizaran Definitely a SC build but outside of ...       NaN
# 19234  New attacker reported:\n\nIP:   139.0.102.26\n...       NaN
# ...                                                  ...       ...
# 19995  🚨 Update🚨 Blumira's security team has been wor...       NaN
# 19996  🚨 Update🚨 Blumira's security team has been wor...       NaN
# 19997  Vigil@nce #Vulnerability of NVIDIA Graphics Dr...       NaN
# 19998  Vigil@nce #Vulnerability of NVIDIA Graphics Dr...       NaN
# 19999  What's your law firm's #cybersecurity policy? ...       NaN
#
#       mb_first_seen mb_last_seen signature file_type reporter origin_country  \
# 19230           NaN          NaN       NaN       NaN      NaN            NaN
# 19231           NaN          NaN       NaN       NaN      NaN            NaN
# 19232           NaN          NaN       NaN       NaN      NaN            NaN
# 19233           NaN          NaN       NaN       NaN      NaN            NaN
# 19234           NaN          NaN       NaN       NaN      NaN            NaN
# ...             ...          ...       ...       ...      ...            ...
# 19995           NaN          NaN       NaN       NaN      NaN            NaN
# 19996           NaN          NaN       NaN       NaN      NaN            NaN
# 19997           NaN          NaN       NaN       NaN      NaN            NaN
# 19998           NaN          NaN       NaN       NaN      NaN            NaN
# 19999           NaN          NaN       NaN       NaN      NaN            NaN
#
#       first_report time_difference time_difference(sec) reference
# 19230          NaN             NaN                  NaN       NaN
# 19231          NaN             NaN                  NaN       NaN
# 19232          NaN             NaN                  NaN       NaN
# 19233          NaN             NaN                  NaN       NaN
# 19234          NaN             NaN                  NaN       NaN
# ...            ...             ...                  ...       ...
# 19995          NaN             NaN                  NaN       NaN
# 19996          NaN             NaN                  NaN       NaN
# 19997          NaN             NaN                  NaN       NaN
# 19998          NaN             NaN                  NaN       NaN
# 19999          NaN             NaN                  NaN       NaN
#
# [770 rows x 18 columns]
