# %%
pip install OTXv2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting OTXv2
#   Downloading OTXv2-1.5.12-py3-none-any.whl (16 kB)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from OTXv2) (2.8.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from OTXv2) (2022.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from OTXv2) (2.23.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil->OTXv2) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->OTXv2) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->OTXv2) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->OTXv2) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->OTXv2) (3.0.4)
# Installing collected packages: OTXv2
# Successfully installed OTXv2-1.5.12

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from OTXv2 import OTXv2,NotFound
import IndicatorTypes
import datetime
import re

class AlienVault:

    API_KEY = 'Your API KEy'  

    SERVER = 'https://otx.alienvault.com/'

    def __init__(self, ioc: str, ioc_type: str,source_date: str=None) -> None:

        self.ioc = ioc

        self.otx = OTXv2(AlienVault.API_KEY, AlienVault.SERVER)

        self.status = None
        self.pulse_count = None
        self.score = None
        self.alert_length = None
        self.alerts = None
        self.cve = None
        self.first_submission_date = None
        self.first_submission = None
        self.first_submission_diff = None
        self.first_submission_diff_sec = None

        if ioc_type.lower() in ['hash']:
            self.hash(ioc)

        elif ioc_type == 'url':
            self.url(ioc)

        elif ioc_type == 'ip':
            self.ip(ioc)

        elif ioc_type == 'domain':
            self.domain(ioc)

        self.getDateDifference(source_date)

        del self.otx

    def get_response(self,ioc_type,ioc):

        response = 'RetryError'

        for _ in range(2):
            try:
                response = self.otx.get_indicator_details_full(ioc_type, ioc)
                break

            except NotFound:
                response = 'NotFound'
                break
            
            except Exception as e:
                print(e)  
        
        return response

    def getValue(self,results, keys):
        if type(keys) is list and len(keys) > 0:

            if type(results) is dict:
                key = keys.pop(0)
                if key in results:
                    return self.getValue(results[key], keys)
                else:
                    return None
            else:
                if type(results) is list and len(results) > 0:
                    return self.getValue(results[0], keys)
                else:
                    return results
        else:
            return results


    def hash(self, hash):

        ioc_type = IndicatorTypes.FILE_HASH_MD5
        if len(hash) == 64:
            ioc_type = IndicatorTypes.FILE_HASH_SHA256

        response = self.get_response(ioc_type, hash)

        if type(response) == str:
            self.status = response
            return

        
        self.pulse_count = self.getValue(response, ['general','pulse_info','count'])
        
        self.score = self.getValue(response,['analysis','analysis','plugins','cuckoo','result','info','combined_score'])

        alerts = []

        avg = self.getValue(response, ['analysis', 'analysis',
                   'plugins', 'avg', 'results', 'detection'])
        if avg:
            alerts.append(avg)

        clamav = self.getValue(response, ['analysis', 'analysis',
                        'plugins', 'clamav', 'results', 'detection'])
        if clamav:
            alerts.append(clamav)

        avast = self.getValue(response, ['analysis', 'analysis',
                        'plugins', 'avast', 'results', 'detection'])
        if avast:
            alerts.append(avast)

        microsoft = self.getValue(response, ['analysis', 'analysis', 'plugins',
                            'cuckoo', 'result', 'virustotal', 'scans', 'Microsoft', 'result'])
        if microsoft:
            alerts.append(microsoft)

        symantec = self.getValue(response, ['analysis', 'analysis', 'plugins',
                            'cuckoo', 'result', 'virustotal', 'scans', 'Symantec', 'result'])
        if symantec:
            alerts.append(symantec)

        kaspersky = self.getValue(response, ['analysis', 'analysis', 'plugins',
                            'cuckoo', 'result', 'virustotal', 'scans', 'Kaspersky', 'result'])
        if kaspersky:
            alerts.append(kaspersky)

        suricata = self.getValue(response, ['analysis', 'analysis', 'plugins',
                            'cuckoo', 'result', 'suricata', 'rules', 'name'])
        if suricata and 'trojan' in str(suricata).lower():
            alerts.append(suricata)

        self.alert_length = len(alerts)

        self.alerts = ', '.join(alerts)

        if (self.pulse_count == 0 or self.pulse_count is None ) and (self.score == 0 or self.score is None) and self.alert_length == 0:
            self.status = 'Clean'
            return

        date = self.getValue(response,['analysis','analysis','datetime_int'])
        
        if date:
            try:
                self.first_submission_date = datetime.datetime.strptime(date, '%Y-%m-%dT%H:%M:%S')
            except Exception as e:
                print(f'Date Error -> {self.ioc} : {e}')
        else:
            created_dates = []
            for pulse in self.getValue(response,['general', 'pulse_info', 'pulses']):
                if pulse:
                    try:
                        created_date = datetime.datetime.strptime(pulse['created'][:19],'%Y-%m-%dT%H:%M:%S')
                        created_dates.append(created_date)
                    except Exception as e:
                        print(f'Pulse date error -> {self.ioc} : {e}')
            
            self.first_submission_date = min(created_dates)

        self.status = 'Malicious'

        self.find_cve(response)

        return


    def url(self,url_address):

        ioc_type = IndicatorTypes.URL

        response = self.get_response(ioc_type, url_address)

        if type(response) == str:
            self.status = response
            return

        alerts = []

        google = self.getValue(response, ['url_list', 'url_list', 'result', 'safebrowsing'])

        if google and 'response_code' in str(google):
            alerts.append('malicious')

        clamav = self.getValue(response, ['url_list', 'url_list', 'result', 'multiav', 'matches', 'clamav'])

        if clamav:
            alerts.append(clamav)

        avast = self.getValue(response, ['url_list', 'url_list','result', 'multiav', 'matches', 'avast'])

        if avast:
            alerts.append(avast)

        self.alert_length = len(alerts)

        self.alerts = ', '.join(alerts)

        #self.pulse_count = self.getValue(response, ['general','pulse_info','count'])

        if self.alert_length == 0:
            self.status = 'Clean'
            return

        date = self.getValue(response,['analysis','analysis','datetime_int'])

        if date:
            try:
                self.first_submission_date = datetime.datetime.strptime(
                    date, '%Y-%m-%dT%H:%M:%S')
            except Exception as e:
                print(f'Date Error -> {self.ioc} : {e}')

        self.status = 'Malicious'

        self.find_cve(response)

        return


    def ip(self, ip_address):
        ioc_type = IndicatorTypes.IPv4

        response = self.get_response(ioc_type, ip_address)
        if type(response) == str:
        	self.status = response
        	return
        alerts = []
        created_dates=[]
        google = self.getValue(response, ['url_list', 'url_list', 'result', 'safebrowsing'])

        if google and 'response_code' in str(google):
            alerts.append('malicious')
        malware=self.getValue(response,['malware','data'])
        length=len(malware)
        if length>0:
        	for ind in range(0,length):
        		date_key=response['malware']['data'][ind]
        		avg = response['malware']['data'][ind]['detections']['avg']
        		if avg:
        			alerts.append(avg)
        			try:
        				date = datetime.datetime.strptime(date_key['date'][:19], '%Y-%m-%dT%H:%M:%S')
        				created_dates.append(date)
        			except Exception as e:
        				print(f'Pulse date error -> {self.ioc} : {e}')
        		clamav = response['malware']['data'][ind]['detections']['clamav']
        		if clamav:
        			alerts.append(clamav)
        			try:
        				date = datetime.datetime.strptime(date_key['date'][:19], '%Y-%m-%dT%H:%M:%S')
        				created_dates.append(date)
        			except Exception as e:
        				print(f'Pulse date error -> {self.ioc} : {e}')
        				
        		avast = response['malware']['data'][ind]['detections']['avast']
        		if avast:
        			alerts.append(avast)
        			try:
        				date = datetime.datetime.strptime(date_key['date'][:19], '%Y-%m-%dT%H:%M:%S')
        				created_dates.append(date)
        			except Exception as e:
        				print(f'Pulse date error -> {self.ioc} : {e}')
        		msdefender = response['malware']['data'][ind]['detections']['msdefender']
        		if msdefender:
        			alerts.append(msdefender)
        			try:
        				date = datetime.datetime.strptime(date_key['date'][:19], '%Y-%m-%dT%H:%M:%S')
        				created_dates.append(date)
        			except Exception as e:
        				print(f'Pulse date error -> {self.ioc} : {e}')
        self.alert_length = len(alerts)
        self.alerts = ', '.join(alerts)
        if self.alert_length == 0:
        	self.status = 'Clean'
        	return
        date = self.getValue(response,['analysis','analysis','datetime_int'])
        if date:
        	try:
        		self.first_submission_date = datetime.datetime.strptime(date, '%Y-%m-%dT%H:%M:%S')
        	except Exception as e:
        		print(f'Date Error -> {self.ioc} : {e}')
        self.status = 'Malicious'
        self.find_cve(response)
        return

    def domain(self,domain_name):

        response = self.get_response(IndicatorTypes.HOSTNAME, domain_name) or self.get_response(IndicatorTypes.DOMAIN, domain_name)
        print(type(response))
        if type(response) == str:
            self.status = response
            return
        alerts = []
        created_dates=[]
        malware=self.getValue(response,['malware','data'])
        length=len(malware)
        print(length)
        if length>0:
        	for ind in range(0,length):
        		date_key=response['malware']['data'][ind]
        		avg = response['malware']['data'][ind]['detections']['avg']
        		if avg:
        			alerts.append(avg)
        		clamav = response['malware']['data'][ind]['detections']['clamav']
        		if clamav:
        			alerts.append(clamav)
        		avast = response['malware']['data'][ind]['detections']['avast']
        		if avast:
        			alerts.append(avast)
        		msdefender = response['malware']['data'][ind]['detections']['msdefender']
        		if msdefender:
        			alerts.append(msdefender)
        print(alerts)
        print(len(alerts))
        self.alert_length = len(alerts)
        print(len(alerts))
        print(self.alert_length)
        self.alerts = ', '.join(alerts)
        if self.alert_length == 0:
        	self.status = 'Clean'
        	return
        date = self.getValue(response,['analysis','analysis','datetime_int'])
        print(date)
        if date:
        	try:
        		self.first_submission_date = datetime.datetime.strptime(date, '%Y-%m-%dT%H:%M:%S')
        	except Exception as e:
        		print(f'Date Error -> {self.ioc} : {e}')
        self.status = 'Malicious'
        self.find_cve(response)
        return
        

    def find_cve(self,response):

        cve_expression=r"\bCVE-\d{4}-\d{4,7}\b"
        content_text = str(response)
        
        result = re.findall(cve_expression, content_text, re.IGNORECASE)

        self.cve = ', '.join(list(set(elements.upper() for elements in result)))
        return

    
    def getDateDifference(self, source_date, date_format=r'%Y-%m-%d %H:%M:%S'):

        if self.first_submission_date is None:
            return

        try:
            source_date = datetime.datetime.strptime(source_date, date_format)
        except Exception as e:
            print(e)
            return
        print(source_date)
        print(self.first_submission_date)
        if source_date < self.first_submission_date:
            print("Twitter")
            duration = self.first_submission_date - source_date
            print(duration)
            self.first_submission = 'Twitter'
            self.first_submission_diff = duration
            self.first_submission_diff_sec = duration.total_seconds()
            return

        elif source_date > self.first_submission_date:
            print("Alienvault")
            duration = source_date - self.first_submission_date

            self.first_submission = 'AlienVault'
            self.first_submission_diff = duration
            self.first_submission_diff_sec = duration.total_seconds()
            return
        print(self.first_submission)
        print(self.first_submission_diff)
        print(self.first_submission_diff_sec)
        print(self.pulse_count)
        print(self.score)

# %%
import time
import pandas as pd
from concurrent.futures import ThreadPoolExecutor

start_time = time.time()

# Field names for the dataset
fields_name = ['tweet_date', 'account', 'ioc_type', 'ioc_value', 'type_of_attack', 'tweet_url', 'text','status', 'pulse_count','score','alert_length','alerts','cve','first_submission_date',
               'first_submission', 'first_submission_diff', 'first_submission_diff_sec']


# To read saved local copy of database
df = pd.read_csv('/content/drive/MyDrive/Twitter_Work_Code/TIP/AV/AV_Output_Non_CVE.csv',names=fields_name, encoding='utf-8',engine='python')

# %%
df

# %%
def report(index):

    if df.loc[index, 'status'] in ['Malicious', 'Clean']:
        return

    ioc = df.loc[index, 'ioc_value']
    ioc_type = df.loc[index, 'ioc_type']
    source_date = df.loc[index,'tweet_date']
    source_date=source_date[:19]
    av = AlienVault(ioc, ioc_type, source_date)

    print(index, ioc, av.status)

    df.loc[index, 'status'] = av.status
    df.loc[index, 'pulse_count'] = av.pulse_count
    df.loc[index, 'score'] = av.score
    df.loc[index, 'alert_length'] = av.alert_length
    df.loc[index, 'alerts'] = av.alerts
    df.loc[index, 'cve'] = av.cve
    df.loc[index, 'first_submission_date'] = av.first_submission_date
    df.loc[index, 'first_submission'] = av.first_submission
    df.loc[index, 'first_submission_diff'] = av.first_submission_diff
    df.loc[index, 'first_submission_diff_sec'] = av.first_submission_diff_sec
    print(df.loc[index, 'status'])
    print(df.loc[index, 'first_submission_date'])
    print(df.loc[index, 'first_submission'] )
    return
start = 300000
end = 350000

AlienVault.API_KEY = '21f702b35f39631cbf89168e5cf20ebb26c61a9c36366118cf23584c11b8ad60'

indices = list(range(30000,50000))

try:
    with ThreadPoolExecutor(max_workers=10) as executor:

        executor.map(report, indices)

        executor.shutdown(wait=True)

except Exception as e:
    print(e)

print(df)

df.to_csv('/content/drive/MyDrive/Twitter_Work_Code/TIP/AV/AV_Output_Non_CVE.csv', index=False)

end_time = time.time()

print(f'\nTime : {end_time - start_time : .2f}')
# Out:
# Streaming output truncated to the last 5000 lines.
# None
# 37386 https://cve.mitre.org/news/archives/2021/news.html#March222021_DeepSurface_Added_as_CVE_Numbering_Authority_CNA NotFound
# NotFound
# None
# None
# 37397 http://ong33download.com NotFound
# NotFound
# None
# None37407 37412 https://t.co/f46EiaxmJS NotFound
# https://otx.alienvault.com/pulse/6058ed45d99db72212fb68d5 NotFound
# NotFound
# NotFound
# None
#
# None
# None
# None
# 37448 http://joingrup-wa.xyz/Curlnya.zip NotFound
# NotFound
# None
# None
# 37479 http://alltokyos.org NotFound
# NotFound
# None
# None
# 37442 http://www.myetherwallete.vip/#/access-my-wallet NotFound
# NotFound
# None
# None
# 37499 http://dcvseutefrvcsdgd.club/ NotFound
# NotFound
# None
# None
# 37509 http://02customer-help832.com/ NotFound
# 37493 http://23.251.62.2 NotFound
# NotFound
# None
# None
# NotFound
# None
# None
# 37458 http://hhhuwsn.club/sharepoint%20/share.zip NotFound
# NotFound
# None
# 37510 http://wallets-paxful.com/trade/paxful/l.php NotFound
# NotFound
# None
# None
# None
# 37515 http://monespacelcl.com/ NotFound
# NotFound
# None
# None
# 37516 http://amandaanderson5364343.link/ NotFound
# NotFound
# None
# None
# 37529 https://malwaredevil.com/2021/03/23/esb-2021-0993-suse-evolution-data-server-multiple-vulnerabilities/?utm_campaign=twitter&utm_medium=twitter&utm_source=twitter NotFound
# NotFound
# None
# None
# 37538 http://customersupport-lloydbank.com/37535 http://crystaloscillatormall.com/ceramic.zip NotFound
#  NotFound
# None
# None
# NotFound
# NotFound
# None
# None
# 37550 http://hbsaves.com/ NotFound
# NotFound
# None
# None
# 3754037561 http://inc-suppuspes.com/chase.zip NotFound
# NotFound
# None
#  https://urlscan.io/search/#page.asn%3AAS22612%20AND%20filename%3Ajquery.payment.js NotFound
# NotFound
# None
# None
# None
# 37566 http://inc-suppuspes.com/service.zip NotFound
# NotFound3756937567 http://importanting.com/privacy-policy/ NotFound
# 37585 http://pay-auth.com/ NotFound
#
# Nonehttp://newpayee-seconline.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=a684eceee76fc522773286a895bc8436&amp;ID=EMR6S4M1NXZSGRKWEVJ760YS7H22T9RDAWKGK8XA8VX0468FWU0UXGF1XK NotFound
# 37580 http://o2updatedue-billing.com/ NotFound
#
# NotFound
# NotFound
# None
# None
# NotFound
# None
# None
# NotFound
# None
# None
# None
# None
# None
# 37586 http://paypal-update-id8798.com/users/userID-16872/season.php?country[.]x=2237a578afcb41ff45cc7916f549ecb72237a578afcb41ff45cc7916f549ecb7 NotFound
# NotFound
# None
# None
# 37634 http://amusedinvest.uno NotFound
# NotFound
# None
# None
# 37596 http://onlinesupport-lloydbank.com/ NotFound
# NotFound
# None
# None
# 37621 http://hbssecaut.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=c0c7c76d30bd3dcaefc96f40275bdc0a&amp;ID=838Z4YXNYRF0E7D9XXW1NLNZKVA79ROJGHP5XS9CMQEE9FS064XC67HI NotFound
# NotFound37590 http://online-cancel-mypayments.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=a5771bce93e200c36f7cd9dfd0e5deaa&amp;ID=JG29WCBYRMCOQKMBC02CZASKKRJYNCOBH7OBVCFWF96CA1E NotFound
# 3760737635 http://watchingsyou.com/privacy-policy/ NotFound
# NotFound
# None
# None
#  NotFound
# None
# None
# http://verify-mynew-payees.com/hsbc/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=642e92efb79421734881b53e1e1b18b6&amp;ID=S5Q38WF7RXLP934M5OZOBG1FOLNTILRG85228HDQ26JRYFS8RK6YQ
# None NotFound
# None
#
# NotFound
# None
# None
# 37546 http://db-campaiggn.com/login/ NotFound
# NotFound
# None
# None
# 37673 http://botydoroboty.sk NotFound
# NotFound
# None
# None
# 37716 http://crpu-verifiction-reference.com/ NotFound
# NotFound
# None
# None
# 3772537688 https://reconshell.com/vulnerabilities-in-mcafee-epolicy-orchestrator/ NotFound
# NotFound
# None
# None
# 37684 http://cirugiaplasticamiguelalarcon.com/wordpress-5.7-es_MX.zip NotFound
# NotFound
# None
# None
#  https://t.co/U8SfIXvHmx NotFound
# NotFound
# None
# None
# 37701 http://new-hs-unregistered-device.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=c9f0f895fb98ab9159f51fd0297e236d&amp;ID=NVXZMWPWUJK6KMXVHIX931Q9LJGLYSP66PTYH14529Y26 NotFound
# NotFound
# None
# None
# 37729 http://keyfiacibadem.com NotFound
# 37752 http://tmuxgmxido.web.app/#maurice.mills@saffronbs.co.uk/ NotFound
# NotFound
# None
# None
# NotFound
# None
# None
# 37748 http://productclips.top/adobe/documents/files/166te939Mbe843GH382CV3834820N39326Ar99/?e= NotFound
# NotFound
# None
# None
# 37756 http://unvalidatedpayee-online.com/HSBC/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=735b90b4568125ed6c3f678819b6e058&amp;ID=1L2VWNPF0WMSAZS7R2ZUESJ4KDADCFFCX8EG5ZJKWHY9K NotFound
# NotFound
# None
# None
# 3779537793 http://easyphshopping.com NotFound
# NotFound
# None
# None
#  http://services-online-banking-accounts.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=a5771bce93e200c36f7cd9dfd0e5deaa&amp;ID=EGZLPJ4G93N8ATHU1RZ81K5LESGKHHH87Q8AS17MHBPPIKL6MZ863 37788 http://investtire.uno NotFound
# NotFound
# None
# None
# NotFound
# NotFound
# None
# None
# 37812 http://103.155.93.138 NotFound37809 http://payeerequest-cancel.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=8613985ec49eb8f757ae6439e879bb2a&amp;ID=FTGKA8B46YNZSYL6GOH6HVKCAG0XPHMUZLTCU6A7J4DIS6WSN8W7USA53C 37810 http://bill-repayments.com/ NotFound
# NotFoundNotFound
# None
#
# NotFound
# None
# 37826 http://device-security-verifification.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=a3f390d88e4c41f2747bfa2f1b5f87db&amp;ID=WQL27SXXGFCSRWIZZ6KWJU9NPBX0I51S0VD3AMJSN2LC5SF8RTJBPJVECLL NotFound
# NotFound
#
# None
# None
# None
# None
# NotFound
# None
# None
# 37840 http://unregistered-payee-authentication.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=98dce83da57b0395e163467c9dae521b&amp;ID=DF7OBHH2CK7OWOBZSQIH5IADY1512BMIX0ENH7FP6XDSZJ2DPFDGCISK NotFound
# NotFound
# None
# None
# 3783037855 http://cryptocorral.com/?read=https%3A%2F%2Fnationalcybersecuritynews.today%2Fgiving%2Dcriminals%2Da%2Dcashflow%2Dcrisis%2Dphishing%2Dscams%2Dphishing%2Dscams%2F NotFound3783337847 37844 https://0day.today/exploit/description/36023 NotFoundhttp://appnew-down.ppkp999.com/download/app/app-mingFaCP-android.apk NotFound http://spmsksdcis.com/1385974ed5904a438616ff7bdb3f7439/16Shop-PP-V1.4.zip NotFound
# NotFound
#
# NotFound
# None
# None
#
# NotFound
# NoneNotFound
# None
# None
#
# None
#  http://whatnotnews.pro NotFound
# None
# None
# 37877 https://t.co/IqdmTTGR1q NotFound37882
#
# NotFound
# None
# None
# NotFound
# None
# None
# https://t.co/QyRwXCBL8B NotFound
# NotFound
# None
# None
# 37887 http://hubplus-events.com/wp/wp-content/themes/access/mufg.jp/32db63696ad74245311ff06268af3b35?cmd=_identifier_Demarrer_ID=5078778613235+_TIme:Wed,Mar,24,2021-12:08am NotFound
# NotFound
# None
# None
# 37902 http://www.aislarefordecopamplona.com/wp-content/themes/access/mufg.jp/f6cb0eb442bc7a9491390395cb10c5b6/?cmd=_identifier_Demarrer_ID=5002754180295+_TIme:Wed,Mar,24,2021-12:11am NotFound
# NotFound
# None37892 http://hubplus-events.com/wp/wp-content/themes/access/mufg.jp/32db63696ad74245311ff06268af3b35/?cmd=_identifier_Demarrer_ID=5078778613235+_TIme:Wed,Mar,24,2021-12:08am NotFound
# NotFound
# None
# None
# 37922 http://168.183.1831.wg61aw1g6wa1ge616ag16w.lipin2010.com/ NotFound
#
# NotFound
# None
# None
# None
# 37939 http://rakuten.co.xymu.cn/?ipk=@w@4355@6744cd62dd652dee50e76f23ce7ff05a NotFound
# NotFound
# None
# None
# 37935 http://rakutan-card.co.jp.kyezga.bar/e-navi/members/settings/card-addition?token=aaaa@example.jp NotFound
# 37901 http://www.aislarefordecopamplona.com/wp-content/themes/access/mufg.jp/f6cb0eb442bc7a9491390395cb10c5b6?cmd=_identifier_Demarrer_ID=5002754180295+_TIme:Wed,Mar,24,2021-12:11am NotFound
# NotFound
# None
# None
# 37957 https://www.cc.uec.ac.jp/blogs/news/2021/03/20210324amazonphishing.html#1 NotFound
# NotFound
# None
# None
# NotFound
# None
# None
# 37977 https://t.co/QegqXhV0XZ NotFound
# NotFound
# None
# None
# 37989 http://gratatata.office-on-the.net/?idm=EzQ02veOpDMs7 NotFound
# 37961 http://homelike.tiantianchecheng.cn/signin/?openid_pape_max_auth_age=http%3A%2F NotFound
# NotFound
# NotFound
# None
# 37985 http://changewill.useramazonexperience.buzz/signin/?openid.pape.max_auth_age=0&amp;openid.return_to=https%3A%2F%2Fwww.amazon.co.jp%2F%3Fref_%3Dnav_em_hd_re_signin&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select NotFound
# NotFoundNone
#
# None
# None
# None
# None36934 http://cel.co.th/ NotFound
# NotFound
#
# None
# None
# 38017 http://rookieed.xyz NotFound
# NotFound
# 38015None
# None
# 38004 http://amazon.nhwfemnkljdsijndm.com/signin/?openid.pape.max_auth_age=0&amp;openid.return_to=https%3A%2F NotFound
# NotFound
# None
# None
#  http://amazon.co.jp.gasiqqwja.buzz/_ap/signin??scid=s_kwa_2015fas_03&amp;lsid=377784&amp;icm_acid=843-606-2618&amp;icm_cid=805384280 NotFound
# NotFound
# None
# None
# 38031 http://thecardyousaved.useramazonexperience.monster/signin/?openid.pape.max_auth_age=0&amp;openid.return_to=https%3A%2F%2Fwww.amazon.co.jp%2F%3Fref_%3Dnav_em_hd_re_signin&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0 NotFound
# NotFound
# None
# None
# 3803238039 http://connectedelevatorer.top/38034 http://www.amazon-check-co-jp.l8c.top/?ddfmk08pftdnjnx0 NotFound
# NotFound
# None
#  NotFound
# NotFound
#  http://digitalmediainstitutes.top/ NotFound
# NotFound
# None
# None
# None
# 38024 http://madeatthe.useramazonexperience.top/signin/?openid.pape.max_auth_age=0&amp;openid.return_to=https%3A%2F%2Fwww.amazon.co.jp%2F%3Fref_%3Dnav_em_hd_re_signin&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select NotFound
# NotFound
# None
# None
# None
# None
# 38043 http://physisaoura.com NotFound
# NotFound
# None
# None
# 38046 http://accountstatus-mobile.xyz/ NotFound
# NotFound
# None
# None
# 38080 http://biogreenwoods.eu/major/was-tokai/ne/jp?uid=aaaa@example.jp NotFound
# NotFound
# None
# None
# 37993 http://saveaccount-billingamzjp.est-le-patron.com/ap/signin?session=8d9f37804f2f8a34bb004d0b45747cb8e1b9008b NotFound
# NotFound
# None
# None
# 38124 http://paypal-expire-id2160.com/users/userID-96564/season.php?country[.]x=98322b047bf40f3a00d0bd73e740135398322b047bf40f3a00d0bd73e7401353 38125 http://paypal-safe-id2318.com/users/userID-34568/season.php?country[.]x=e35955e19e83496cef30de01b9753f6ae35955e19e83496cef30de01b9753f6a3809738081 http://biogreenwoods.eu/major/was-tokai/ne/jp/?uid=aaaa@example.jp 38126NotFound
# 38118 http://cancelsupport-iverify.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=d09bf41544a3365a46c9077ebb5e35c3&amp;ID=4XK0BBOQGGPRZUO0AE11WSVSZ10RBN8KXYC9961HINXLRY0KUW NotFound
# NotFound
# None
# None
#  http://daillyball.com NotFound
# NotFound
# None
#  NotFound38122 http://cashapps23.com NotFound
# NotFound
# None
# None
#
# NotFound
# None
# None
# NotFound
# None
# None
# None
# NotFound38139
#  http://realestateservices-homelisitng.com/ NotFound
# NotFound
# None
# None
# 38123 http://paypal-proved-id4943.com/users/userID-53266/season.php?country[.]x=88376ae947ecbcf8fef57031cf38d85d88376ae947ecbcf8fef57031cf38d85d NotFound
# None
# NotFound
#  http://paypal-security-id2161.com/users/userID-15139/season.php?country[.]x=103622a970989ab66deb897dcb975c88103622a970989ab66deb897dcb975c88 NotFound
# NotFound
# None
# None
# None
# NotFound
# None
# None
# 38150 http://paypal-update-id2139.com/users/userID-13997/season.php?country[.]x=8e18d2469a271a6ae07a021b8e76a0ca8e18d2469a271a6ae07a021b8e76a0ca NotFound
# NotFound
# None
# None
# 38141 http://page-contact-center014569.com NotFound
# NotFound
# 38147 http://remove-app-payee.com/ NoneNotFound
# NotFound
# None
# None
#
# 38175 http://security-hs-payee-support.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=98dce83da57b0395e163467c9dae521b&amp;ID=VHNYD7QQSMTJUV8QS3C5PY7T3E0U26GQZ4D7JEFD8WIOJW NotFound
# NotFound
# None
# None
# None
# 38152 https://securityaffairs.co/wordpress/115896/security/microsoft-exchange-patched.html?utm_source=rss&utm_medium=rss&utm_campaign=microsoft-exchange-patched NotFound
# NotFound
# None
# None
# 38148 http://remove-payee-online.com/ NotFound
# NotFound
# None
# None
# 38181 http://apostatop.site NotFound
# 38163NotFound
# None http://portale-sicuro-pt.com/ NotFound
# NotFound
# None
# None
# 38149 http://paypal-security-id2161.com/users/userID-76169/season.php?country[.]x=c81d1e9fe656a29042796e604a7351f6c81d1e9fe656a29042796e604a7351f6 NotFound
#
# None
# NotFound
# None
# None
# 38206 http://payee-submitted.com/cancel/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=d3d9446802a44259755d38e6d163e820&amp;ID=570MQ5M26RGWYFCSIO1Q64Q2H5B1JDC7E29VJUNS1FO NotFound
# NotFound
# None
# None
# 38209 http://paypal-expire-id2160.com/users/userID-16949/season.php?country[.]x=3bb0aadb97c31a21d3e2283f34443fd23bb0aadb97c31a21d3e2283f34443fd2 NotFound
# NotFound
# None
# None38213 http://paypal-safe-id2318.com/users/userID-49754/season.php?country[.]x=b8ec274888e7a2aa9567b34f6c827f85b8ec274888e7a2aa9567b34f6c827f85 NotFound
# NotFound
# None
# None
#
# 38214 http://hkerstar.com/mazon/ NotFound
# NotFound
# None
# 38208 http://paypal-proved-id4943.com/users/userID-82832/season.php?country[.]x=fa5998f53d896bf7f99cef3bdfde0452fa5998f53d896bf7f99cef3bdfde0452None
#  NotFound
# NotFound
# None
# None38223 http://nrm3sd.com/ NotFound
# NotFound
# None
# None
# 38251 38222 http://o2-updatebillingfailure-via.com/ NotFound
# NotFound
# None
# None38219 http://hugotdagat.com NotFound
# NotFound
# None
# None
#
# http://verify-payee-management-request.com/ NotFound
#
# NotFound
# None
# None
# 38285 https://www.wired.com/story/doj-crack-down-online-scams NotFound
# NotFound
# None
# None
# 38259 http://new-payee-fraud.net/ NotFound
# NotFound
# None
# None
# 38290 https://www.theregister.com/2021/03/24/covid_phishing_2020_palo_alto_networks_research/ NotFound
# NotFound
# None
# None
# 38307 http://puskasaward.com NotFound
# NotFound
# None
# 38294 https://t.co/7O4OBfBs5q 38334 http://removenewunauthorisedpayee.com/ NotFound38306 http://pragocrm.com/crm/core/js/lib_head.js.php?lang=es_ES&amp;layout=classic&amp;version=13[.]0[.]2 NotFound
# 38286 http://addoded.xyz/NotFound
# NotFound
# None
# None
#
# NotFound
# None
# None
#  NotFound
# NotFound
# None
# None
# 38341 http://payee-submitted.com/cancel/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=1c383cd30b7c298ab50293adfecb7b18&amp;ID=0V4YNJRTN6518RW14PQEPVKZMPJRYQ1GWQCJLZMMJUSO75AWX90QRZN3KNTP NotFound
# None
# NotFound
# None
# None
# 38281 http://aplication2yu.ga/good/home/?i=10138 NotFound
# None
# NotFound
# None
# 38343 NotFound
# None
# None
# http://customer-device.com/ NotFound
# NotFound
# None
# None
# 38363 http://realtor-id-1646951499.fishingbooking.net/ NotFound
# NotFound
# None
# None
# 38345 http://page-contact-center019035.com NotFound
# NotFound
# None
# None
# 38367 http://hurrayhuna.com/amazkn/mazon/ NotFound
# NotFound
# None
# None
# 38371 http://hs-online-deactive-payee.com/ NotFound
# NotFound
# None
# None
# 38356 https://www.zdnet.com/article/purple-fox-malware-evolves-to-propagate-across-windows-machines/?ftag=TRE-03-10aaa6b&bhid=20349435164087051497988035248200&mid=13310488&cid=717883459 NotFound
# NotFound
# None
# None
# 38365 http://162.214.123.68 NotFound
# NotFound
# None38392 http://pay-login.com/ NotFound
# NotFound
#
# None
# None
# None
# 38417 38369 http://hs-online-supportpayee.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=9a1158154dfa42caddbd0694a4e9bdc8&amp;ID=KSNREK6JPVWN8FB1D26AKYCXAC6P3GJQLU19Q13V1999F NotFound
# http://www4verifyfifth-third53.com NotFound
# NotFound
# None
# None
# NotFound
# None
# None
# 38354 http://pahx1.com NotFound
# NotFound
# None
# None
# 38451 http://paypalweb.net/paypal/?locale[.]x=es_US NotFound
# NotFound
# None
# None
# 38418 38467http://1158wnss.com/static/uploads/hqylanzhuoapp.apk38471 http://docs.google.com/document/d/e/2PACX-1vQZFgnbYidXJNVM0EqvtJzq6O5x8083xZEubdKsE133o5q9cCqEcH9sLOv87gRgGavIHomfCVjoF96a/pub?embedded=true NotFound
# NotFound
# None
# None38464 http://polar-accurate-watchmaker.glitch.me/ NotFound
# NotFound
# None
# None
#  NotFound
# NotFound
# None
# None
# 38472 http://bitflyer-japan.web.app/ja-jp/ NotFound
#  http://healthsecurity.agency/ NotFound
# NotFound
# None
# None
# 38473
#  https://t.co/DbpGAF8h5a NotFound
# NotFound
# None
# NotFound
# None
# None
# None
# 38483 http://02helpcentre-id237.com/ NotFound
# NotFound
# None
# None
# 38488 http://paypal-activity-ticketid-9278.com/users/userID-64798/en/season.php?country[.]x=07d14f9a56eacc695017d4ee2595dde207d14f9a56eacc695017d4ee2595dde2 NotFound
# NotFound
# None
# None
# 38490 http://personal-payee-advance.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=a684eceee76fc522773286a895bc8436&amp;ID=DDZR890FWA8ILWPB0KJB4AP19RTCX3YQZ3044RNVY438Z893HA74BTL NotFound
# NotFound38528
# None
# None
#  38536 http://informpaymentnotice.com/hsbc/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=8e296a067a37563370ded05f5a3bf3ec&amp;ID=ULF4LDGG7IT01Z89UT0ROY3IVMVNP984U4AN1NC8CZ4TUP2H0GOWZBGR9 NotFound
# NotFound
# None
# None38534 http://infosicurezza.com/ NotFound
# 38493 http://paypal-activate-ticketid-8349.com/users/userID-75312/season.php?country[.]x=72e1beca85f110f2b65a4d7381987a8a72e1beca85f110f2b65a4d7381987a8a NotFound
# NotFoundNotFound
# None
# None
#
# http://riscontro-app-isp.com/ NotFound
# NotFound
#
# None
# None
# 38526 http://proluxlistinghome-realestate.com/ NotFound
# NotFound
# None
# None
# None
# None
# 38541 http://ttienv-rview.com/environmental/industrial/prjct62208/hsv/t0fll.zip NotFound
# NotFound
# None
# None
# 38542 http://callowaycontracting-reviews.com/prjct66629/industrial/builds/ovexhl4/t0fll.zip NotFound
# NotFound
# None
# None
# 38557 http://ttienv-prjct.com/industrial/environmental/prjct6908/remedial/t0fll.zip NotFound
# NotFound
# None
# 38570 http://digi-activatie.com/ NotFound
# None
# NotFound
# None
# None
# 38628 http://ups-suivi-envoi-livraison.website/ NotFound
# NotFound
# None38610
# None
#  http://paribas-34329189.icu/ NotFound
# NotFound
# None
# None
# 38636 http://alsoluciones.work/ht/core/js/lib_head.js.php?lang=en_US&amp;layout=classic&amp;version=13[.]0[.]2 NotFound
# 38645 http://verify-myactivity-payees.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=ed3d2c21991e3bef5e069713af9fa6ca&amp;ID=LB3YTN6EQ3MBFMP57P52ZO4VWSF7TLWBWBEL0U4YTE2NTCCEEDL 38652 http://dirsolusec.info/ NotFound
# NotFoundNotFound
# NotFound
# None
# None
# NotFound38518 http://accesso-anomalo-banking.com/ NotFound
# NotFound
# None
#
# None
# None
# None
#
# None
# None
# 38662 https://therecord.media/i-scrounged-through-the-trash-heaps-now-im-a-millionaire-an-interview-with-revils-unknown/ NotFound
# NotFound
# None
# None
# 38584 http://oktobersnt.com/ NotFound
# NotFound
# None
# None
# 38660 https://www.openssl.org/news/secadv/20210325.txt NotFound
# NotFound
# None
# None
# 38666 http://grooupswhtapp.my03.com/ NotFound
# NotFound
# None
# None
# 38670 http://homee.club NotFound
# NotFound
# None
# None
# 38703 http://paymentinfonotify.com/hsbc/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=35f4a8d465e6e1edc05f3d8ab658c551&amp;ID=B7RF843S8BFAOBDLRFTWJYL4T873FXF04WRN868ESZ8FLS1 NotFound38709 http://hs-bc-online-payee.com/ NotFound
# NotFound
# None
# None
# 38708 http://hs-authenticationcheck.com/
# NotFound
# None
# None
# 38712 http://imthestreamer.com NotFound
#  NotFound38699 http://danielcasson.com NotFound
# NotFound
# None
# None
#
# NotFound
# None
# None
# 38741 http://online-banking-accounts.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=e4da3b7fbbce2345d7772b0674a318d5&amp;ID=MFOUSM3IY1QYYVJP5G8ILY88SUT5YGZK00HFN405TXLLI 38721 http://loginaccesswebmail.moonfruit.com/ NotFound
# NotFound
# None
# NotFound
# None
# None
# 38668 http://209.126.1.227 NotFound
# NotFoundNone
#
# None
# None
# NotFound
# NotFound
# None
# None
# 38761 http://services-online-banking-logon.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=6364d3f0f495b6ab9dcf8d3b5c6e0b01&amp;ID=3DX04QE870F370M5OAYT2OEMNQWMR2OLHG781ML3G3PBTAYSIJAG NotFound
# NotFound
# None
# None38776
# 38800 http://galleryofstyle.by///wp-content/themes/form/SMBC/6693706c1d4bd8257927351524e6199c?cmd=_identifier_Demarrer_ID=322534392529+_TIme:Fri,Mar,26,2021-3:55am http://auth-cancellations.com/hsbc/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=4e732ced3463d06de0ca9a15b6153677&amp;ID=3YKI1WS2I2X2A8JHBR7S0CHJ1HTCG3P6PN7T7MDA56TNotFound
# NotFound
# None
# None
# 38802 http://galleryofstyle.by/wp-content/themes/form/SMBC/6693706c1d4bd8257927351524e6199c/?cmd=_identifier_Demarrer_ID=322534392529+_TIme:Fri,Mar,26,2021-3:55am NotFound
# NotFound
# 38789 http://myshopigfy.com NotFound
# NotFound
# None
# None
# 38750 https://www.defenseone.com/ideas/2021/03/bum-rushing-extremists-military-might-not-help/172740/ NotFound
# NotFound
# None38823 http://apple.com.jp.zqsygl.com/account/?view=login&amp;appIdKey=16aa4fd166a4ded&amp;country=JP NotFound
# NotFound
# None
# None
#  NotFound
# NotFound
# None
# None
#
# None
# 38830 http://auth-cancellations.com/hsbc/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=812b4ba287f5ee0bc9d43bbf5bbe87fb&amp;ID=4J8K622TB7H4YI5B3HT8AJV9T21RJL9PMNDJMK7NC8XV447WY6I468G72FVGH NotFoundNone
# None
#
# NotFound
# None
# None
# 38892 http://failure-o2billing-via.com/ NotFound
# NotFound
# None
# None
# 38849 http://highcountry.builders NotFound
# NotFound
# None
# 38898 http://hs-accountprotection-reset-devicepairing.com/ NotFound
# NotFound
# None
# 38920 http://bot-4518.com/ NotFound
# NotFoundNone
# None
# 38839
# None
# None
# 38832 http://hiperformancebikes.top/http://fantimail.xyz NotFound
# NotFound38902 NotFound
# NotFound
# None
# None
#  http://hs-newpayeecheck.com/ 38838 http://confirmmynewpayee.info/hsbc/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=6f4922f45568161a8cdf4ad2299f6d23&amp;ID=UUWBMOVJ8A6QFFFB4GC5DZD1INAJ911YAAS84XWGQMYI224 NotFound
# NotFound
# None
# None
#
# None
# None
# NotFound
# NotFound
# None
# None
# 38933 http://login-device-authorisation.com/38970 NotFound
# NotFound
# None
# None
#  38926 http://fundmanagerprogram.net NotFound
# http://micheltahan.com/mazon/a715a/NotFound
# None
# None
#  NotFound
# NotFound
# None
# None
# 38972 http://page7634438fbk.com/ NotFound
# NotFound
# None
# None
# 3880438978 http://paypal-invaild-id2925.com/users/userID-19536/season.php?country[.]x=fa204992a29e6c60fc95411ce501f810fa204992a29e6c60fc95411ce501f810 NotFound
# NotFound
# None
# None
#  https://t.co/RRrsijinVh NotFound
# NotFound
# None
# None
# 38973 http://page-contact-center01543.com NotFound38975 http://page-contact-center10246.com NotFound
#
# NotFound
# None
# None
# NotFound
# None
# None
# 38987 http://review-online-request.com/ NotFound
# NotFound
# None
# None
# 38980 http://paypal-vaildate-ticketid-8525.com/users/userID-28571/season.php?country[.]x=54fa18ff1f77d8799b94b6ecde06830454fa18ff1f77d8799b94b6ecde068304 NotFound
# NotFound
# None
# None
# 38989 http://lcl-particuliers-monespaces-clients-lcl-voscompteslcldirw.com/_templates/ NotFound
# NotFound
# None
# None
# 39002 http://seucrhelp.com/ NotFound
# NotFound
# None
# None
# 39003 http://sic-netflix.com/ NotFound
# 38992 http://security-hs-transaction-alertsupport.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=f7177163c833dff4b38fc8d2872f1ec6&amp;ID=EZHW8C0CO1XTH591Q79M0JL3WTIVE5DYDSXBO1IBD1ZIAJ5E64LSDGB2T0KF4 NotFound
# 38979 http://paypal-valid-ticketid-8525.com/users/userID-66167/season.php?country[.]x=dac8c18b7e4411c4419b756792fb3de4dac8c18b7e4411c4419b756792fb3de4 NotFound
# NotFound
# None
# None
# NotFound
# 39050 http://online-mypayments-login.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=28dd2c7955ce926456240b2ff0100bde&amp;ID=BTP47O34RFGOV22TWUN09Q6DFL00WD0HYQ1VL0Y3KCACCD NotFound
# NotFound
# None
# None
# None
# None
# NotFound
# None
# None
# 39062 http://amazon-en-signin.com/ NotFound
# 39065 NotFound
# None
# None
# http://lloyd-helpsecure.com/ NotFound
# NotFound
# None
# None
# 39053 https://app.any.run/tasks/48cad164-704d-459b-ae32-6be7365a23bd NotFound
# NotFound
# None
# None
# 39138 http://1952.news NotFound
# NotFound
# None
# None
# 39147 39094 http://venmosupportt.com/keep%20dulu%20venmo%20update.zip NotFound
# NotFound
# None
# None
# http://3dinfosecurity.com/ NotFound
# NotFound
# None
# None39120 http://www.verificapostepay.com/jod-fcc/fcc-authenticazione.php NotFound
# NotFound
# 39123 https://app.any.run/tasks/4b4870d4-4290-4b65-9287-9e2e77db9f52 NotFound
# NotFound
# None
# None
#
# None
# None
# 39154 http://smmms01.hyperphp.com/ NotFound
# NotFound
# None
# None
# 39163 http://capitalplusone.com/ NotFound
# NotFound
# None
# None
# 39156 http://185.27.134.213 NotFound
# 39181 https://ift.tt/3lTZ5kc NotFound
# NotFound39190 https://t.co/dfhfB7awSu NotFound
# NotFound
# None
# NoneNotFound
# None
#
#
# None
# None
# None39198 http://madheshtimes.com/wp-content/themes/jp1/MUFG/dfcc052ef68caeb124c919955aab0821?cmd=_identifier_Demarrer_ID=7009579388996+_TIme:Sat,Mar,27,2021-12:02am NotFound39199
#
# 39205NotFound
# None
# None
#  http://madheshtimes.com/wp-content/themes/jp1/MUFG/de4d6373bdb938a9111eecc1cb14f782?cmd=_identifier_Demarrer_ID=1821537963232+_TIme:Sat,Mar,27,2021-12:08am NotFound
# 39192NotFound
#  http://madheshtimes.com/wp-content/themes/jp1/MUFG/dfcc052ef68caeb124c919955aab0821/?cmd=_identifier_Demarrer_ID=7009579388996+_TIme:Sat,Mar,27,2021-12:02amNone NotFound
# NotFound
# None
# None
#
# None
#  http://madheshtimes.com/wp-content/themes/jp1/MUFG/ NotFound
# NotFound
# None
# None
# 39206 http://madheshtimes.com/wp-content/themes/jp1/MUFG/de4d6373bdb938a9111eecc1cb14f782/?cmd=_identifier_Demarrer_ID=1821537963232+_TIme:Sat,Mar,27,2021-12:08am NotFound
# NotFound
# None
# None
# 39216 http://google.com@taiyo.com.sg/wordpress/index.php? NotFound
# NotFound
# None39210 https://otx.alienvault.com/pulse/60219f6bdc6edbc5308da56b/?source=email_notification
#  NotFound
# NotFound
# None
# None
# None
# 3920939222 http://www.shrimadkoba.org/images/webmail-op.jp/webmail-op.jp/?cgitoken NotFound
#  https://otx.alienvault.com/pulse/6021a425750b50dafcc48a26/?source=email_notification NotFound
# NotFound
# NotFound
# None
# None
# None
# None
# 39221 http://www.shrimadkoba.org/images/webmail-op.jp/?uid=aaaa@example.jp NotFound
# 39233 NotFound
# None39215 http://example.jp.s37mw37s.32102212632121.bankingen.com./#aHR0cDovL2dvb2dsZS5jb21AdGFpeW8uY29tLnNnL3dvcmRwcmVzcy9pbmRleC5waHA/ NotFound
# NotFound
# None
# None
# http://hsbc-secure-payment.com/login/login.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=28dd2c7955ce926456240b2ff0100bde&amp;ID=66BTQKWPDDLG4E70IZQ2PS4PNSTMSOHBY6Z8JRFZ8DOCXZV NotFound
# 39227 http://www.myetherwallett.vip/#/access-my-wallet NotFound
# None
# None
# NotFound
# NotFound
#
# None
# None
# None
# 39293 http://amazon.co.jp.anacetm328.buzz/ap/signin.php?openid.pape.max_auth_age=0&amp;openid.return_to=%9815c53af363efb0910730a2f11dfb31f1fa1c40 NotFound
# NotFound
# None
# None
# 39253 http://454gh55.buzz/signin/?openid.pape.max_auth_age=0&amp;openid.return_to=https%3A%2F%2Fwww.amazon.co.jp%2F%3F_encoding%3DUTF8%26ref_%3Dnav_ya_signin&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select NotFound
# NotFound
# None
# None
# 39337 http://sciechimiche.org NotFound
# NotFound
# None
# None
# 39335 http://icloud.app.com-support.care/?U=1&amp;I=5&amp;D=0891 NotFound
# NotFound39296 http://cr-mufg.7566321.com/?Login NotFound
# NotFound
# None
#
# 39238 http://rakuten.co.62dir.com/?ipk=@n@4987@d652a5e0ab0481b3e87afbcd167731f0 NotFound39342 http://hs-mobile-device.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=ac627ab1ccbdb62ec96e702f07f6425b&amp;ID=RBTFO7NY56T2J581948K0NBUKGDYAP65SBL6UG1TJCHJLZHDBN152T8YB NotFound
# NotFound
# None
# None
# None
# None
#
# NotFound
# None
# None
# None
# 39354 http://cdszqc.com/ggdywjj/ag88_files/ag88.apk NotFound
# NotFound
# None
# None
# 39357 http://fanpage-contact-center912350.com NotFound
# NotFound39279 http://anazon-servicoo.net/signin/?openid.pape.max_auth_age=0&amp;openid.return_to=https%3A%2F%2Fwww.amazon.co.jp%2F%3Fref_%3Dnav_em_hd_re_signin&amp;openid.identity=http%3A%2F NotFound
# NotFound
#
# None
# None
# None39346 http://hlfxsecurepayee.com/ NotFound
# None
#
# NotFound39374 http://clientlcl.com/ NotFound
# NotFound
# None
# None
#
# None
# None
# 3938339384 http://onlinebanking-revokepayee.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=45c48cce2e2d7fbdea1afc51c7c6ad26&amp;ID=3XAQ0LUD5GM9QIGCLBQ9A9ZDPY1K1D8545ECE3ZASXAHBBZQ NotFound
# NotFound 39382 http://austasconcepts.com/autaz.zip NotFound
# http://online-banking-accounts-services.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=9bf31c7ff062936a96d3c8bd1f8f2ff3&amp;ID=IXJA95LL596RP0C6LLNQY2NCEXICD10T5XNCCTX75T NotFound
# NotFound
# NotFound
# None
# None
#
# None
# None
# None
# None
# 38948 http://rosegibbon.club/L9.zip NotFound
# NotFound
# None
# None
# 39386 39390 http://page5238573fbk.com/ NotFoundhttp://marketplace-post289332.com/ NotFound39421 http://removal-newpayment.com/hsbc/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=6f4922f45568161a8cdf4ad2299f6d23&amp;ID=75OAN4UE2153HDWW1IJ3HBRDGXVD6N3KGZV598PG1MANRO2BL NotFound
# NotFound
# None
# None
#
# NotFound
# None
# None
#
# 39436 http://secure-verifypayee.page/ NotFound
# NotFound
# None
# NoneNotFound
# None
# None
#
# 39489 http://twistedvinelandscape.com/ NotFound
# NotFound
# None
# None
# 3942339410 http://yardimlasmazamanii.com NotFound
#  http://review-mynew-transaction.com/hsbc/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=d09bf41544a3365a46c9077ebb5e35c3&amp;ID=I5W5ESOO0R5F35GG5PCGKZE0ZAS9WEPYOFJM4PYBX114X3JLBB5VBD6JH NotFound
# NotFound
# None
# None
# NotFound
# None
# None
# 39491 http://192.163.202.169 NotFound
# NotFound
# None
# None
# 3941139499 39493http://confirmmypayee.com/hsbc/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=6364d3f0f495b6ab9dcf8d3b5c6e0b01&amp;ID=146OFKA3NCEQ9BVJD2HCO3M6VQ2W1358L6XUTQN5U39535 http://verify-mynew-transaction.com/hsbc/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=98f13708210194c475687be6106a3b84&amp;ID=3UTNECE87R4XGTLBOPUWMKK84JXURECODWHULK88XZFQMG NotFound
# NotFound
#  NotFound
#  http://minkulo35.com/mazon/ NotFound
#  http://fanpage-contact-center038529.com NotFound
# NotFound
# NotFound
# None
# None
# NotFound
# None
# None
# None
# None
# None
# None
# 39530 http://secure-icancelproceed.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=98dce83da57b0395e163467c9dae521b&amp;ID=WDQDHXBJ3ODA9HLSJODYIGGR46VSGQEOVOH6H7T0T4YGZFI NotFound
# NotFound
# None
# None
# 39551 https://pastebin.com/D2dZgivB NotFound
# NotFound
# None
# None
# 395883958139556 http://us-infodepartcenteramzapp.com/ NotFound
# NotFound
# None
# None
#  http://abicorp.net/dolibarr/htdocs/core/js/lib_head.js.php?lang=fr_FR&amp;layout=classic&amp;version=14[.]0[.]0-alpha NotFound
# NotFound
# None
# None
#  http://giantchameleon.com/sdpdx/iefsz/?ts=1616915633094 NotFound
# NotFound
# None
# None
# 39621 http://failedregistrations-newpayee.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=c16a5320fa475530d9583c34fd356ef5&amp;ID=ZREF913TBP0FH2OD60F7EUKEFEERZJB00HBZUIKUE NotFound
# NotFound
# None
# None
# 39599 http://jseav.com NotFound
# NotFound
# None
# None3962939613 http://faculty-advanced-secure.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=c4ca4238a0b923820dcc509a6f75849b&amp;ID=G4C4POLJHZD7JIANPXEDO8O6CY4NPNE5S55GET5MDKMWOO4FZ9D4EB NotFound
# 39620 http://failedregistrations-newpayee.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=3c59dc048e8850243be8079a5c74d079&amp;ID=HPZI5I1CPFX7FNKA7MSDW2EFUS08JAD3WX3KBTK8UB78YN
# 39624 http://block-payee-online-banking.com/Login.php NotFound
# NotFound
# None
# None
#  NotFound
#  https://paper.li/MagneSvendsen/1459938610?edition_id=308618d0-8fb1-11eb-956d-fa163e65ae25 NotFound
# NotFound
# None
# None
# NotFound
# None
# None
# NotFound
# None
# None
# 39631 http://online-mydebit-payments.com/ NotFound
# NotFound
# None
# None
# 39633 http://online-banking-secure-login.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=d82c8d1619ad8176d665453cfb2e55f0&amp;ID=7VJNDTSYS1B4PUDQ40HKTOY2XVV6IEL2EFMOHII2RIOWWQMKPS NotFound
# NotFound
# None
# None
# 39630 http://certifynewly-addedpayee.com/ NotFound
# NotFound
# None
# None
# 39667 http://onlineupdateyourinfo.com/web/auth/ NotFound
# NotFound
# None
# None
# 39685 http://proluxury-homelisting.com/39639 NotFound
#  http://online-unauthorize-device.com/ NotFound
# NotFoundNotFound
# None
# None39636 http://online-banking-secure-logon.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=a1d0c6e83f027327d8461063f4ac58a6&amp;ID=6SJZUOCDWXM64PT6Q65PW9VLRU4YTL9JPC8KAF2RSYXH1NK NotFound
# NotFound
# None
# None
#
# None
# None
# 39641 http://online-not-recognised.com/ NotFound
#
# NotFound
# None
# None
# 39658 http://halidevice-attempt.com/Login.php NotFound
# NotFound
# None
# None
# 39689 39687 http://postmarketingpremiumservices.live/bbestdrivemmner/mazon/ NotFound
# http://hs-online-revokepayee.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=32bb90e8976aab5298d5da10fe66f21d&amp;ID=5RS6V06I8FALJT6WFRJZUB7RWY537PNC0O4J9KKHI NotFound
# NotFound
# None
# NotFound39686
# None
# None
# None
# 39692 http://remove-online-banking-payee.com/ NotFound
#  http://info-2021.com/ NotFound
# NotFoundNotFound
# None
# None
#
# None
# None
# 39695 http://management-payee-request-verify.com/ NotFound
# NotFound
# None
# 39714 https://t.co/SfVTmQUgEC NotFound
# NotFound
# None
# None
# None
# 39696 http://management-payee-request-verify.com/Login.php NotFound
# NotFound
# None
# None
# 39716 http://secure-my-payeeinfo.com/ NotFound39726 http://secure-payee-removal.org/ NotFound
# NotFound
# NotFound
# None
# None
#
# None
# None
# 39711 http://venmo-claim.com/CASH%20APP%20SC.zip NotFound
# NotFound
# None
# None
# 39736 http://accountoverview-newpayees.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=98f13708210194c475687be6106a3b84&amp;ID=UJHUJW5HM3W8K7RA32PVZQYL4EE4V35DPY7EH7UETNDCUGSB2XTB2 NotFound
# NotFound
# None
# None
# 3976739748  http://accountoverview-newpayees.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=43ec517d68b6edd3015b3edc9a11367b&amp;ID=S4X1FYI7IKFXB9IJNO4HVCXUEWKXN2DC77A80WNEO4ORXC0 NotFound
# http://devicesmanagement-secured.com/ NotFound
# NotFound
# None
# NotFound
# None
# None
# None
# 39758 http://security-proceedsupport.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=28dd2c7955ce926456240b2ff0100bde&amp;ID=4J4N0LP7MOMF6DYSWRQYLAAPD9N385GXC1PIP341SNYQR0TTLQ NotFound
# NotFound
# None
# None
# 39789 http://postaleaccedi.com/ NotFound
# NotFound
# None
# None
# 39822 http://lecoin.shop/wp-content/themes/ssl/jp/b9e056609f10780f896eee0d370f6a80/?cmd=_identifier_Demarrer_ID=3855547150738+_TIme:Sun,Mar,28,2021-8:56pm39821  NotFound
# 39834 http://thecleanseinplace.com/wp-content/themes/ssl/jp/d7f996de6b8472f49aa2e7897a2880c4?cmd=_identifier_Demarrer_ID=3310525682755+_TIme:Mon,Mar,29,2021-2:02amhttp://lecoin.shop/wp-content/themes/ssl/jp/b9e056609f10780f896eee0d370f6a80?cmd=_identifier_Demarrer_ID=3855547150738+_TIme:Sun,Mar,28,2021-8:56pm 39835 http://thecleanseinplace.com/wp-content/themes/ssl/jp/d7f996de6b8472f49aa2e7897a2880c4/?cmd=_identifier_Demarrer_ID=3310525682755+_TIme:Mon,Mar,29,2021-2:02am NotFound
# NotFound
# NotFound
# None
# None
# NotFound
# None
# None
#  NotFound
# NotFound
# None
# None
# NotFound
# 39813 https://t.co/IglUaBmWRu NotFound
# NotFound
# None
# None39859 http://apple.com.hxmuju.com/account/?view=login&amp;appIdKey=72641aaad34cc5b&amp;country=JP NotFound
# NotFound
# None
# None
# None
# None
#
# 39884 http://online-banking-securekey-logon.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=b6d767d2f8ed5d21a44b0e5886680cb9&amp;ID=ZMTNHUW3J30OR75G8UUSL8Y3QZB0C5PP3YOKL9HBEFB77Y NotFound
# NotFound
# None
# None
# 39885 http://online-deregister-device.com/Login.php NotFound
# NotFound
# None
# None
# 39786 http://security-hs-bc-online-banking.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=ad61ab143223efbc24c7d2583be69251&amp;ID=2D5BM49Q9E7O1SC3I54DBRW9T697B5IQIAWRR464PNFR NotFound
# NotFound
# None
# None
# 39925{'detail': 'IP is private.'}
# 39887 https://malwaredevil.com/2021/03/29/esb-2021-1067-alert-apple-ios-apple-products-cross-site-scripting-remote-with-user-interaction/?utm_campaign=twitter&utm_medium=twitter&utm_source=twitter http://secure-hs-payee-removal.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=fc490ca45c00b1249bbe3554a4fdf6fb&amp;ID=20QK54T8BE3YICXDSVWCL7X4VMVHQI3SW8NDC3SQNDR0R6 NotFound
# NotFound39926 http://security-hs-online-payee.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=f7177163c833dff4b38fc8d2872f1ec6&amp;ID=2JAVV9ITW5PRNTTLAZPMW33A4Y0OM560TYHOWVDTFCHKQRNYB7VY NotFound
# NotFound
# None
# 39893 http://payee-secure-security-login.com/ NotFound
# 39902 http://mesguitamesh.com/mazon/ NotFound
# None
#  NotFound
# NotFound
# None
# None
# NotFound
# None
# None
# NotFound
# None
# None
#
# 39929 http://securemobile-banking.com/ NotFound
# NotFound
# None
# None
# None
# None
# {'detail': 'IP is private.'}
# 39901 192.168.255.51 RetryError
# RetryError
# None
# None
# 39932 http://ppalsuspicious.com/ NotFound
# NotFound
# None
# None
# 39953 http://virtualbackers.com/wordpress-5.7.zip NotFound
# NotFound
# None
# None
# 39995 http://universalcreditcards.top/st/ NotFound
# NotFound
# None
# None
# 3999240015 http://9291588.com/ NotFound
#  39987 http://newpayee-accountoverview.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=d1fe173d08e959397adf34b1d77e88d7&amp;ID=89V4V1HTPYZ8U50LSQRR3TLO2MP8WKE9SANC3SE5CU NotFound39978 http://payeealertsnotices.com/hsbc/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=37693cfc748049e45d87b8c7d8b9aacd&amp;ID=O4ZO90U3SSHUG41OSWVTSRSTBXTXLU9RFGDEB3FD3FBFPRCPK24S NotFound
# NotFound
# None
# None
#
# NotFound
# None
# None
# 39961 http://hlifxsecurepayee.com/ NotFound
# NotFound39971 http://online-banking-security-login.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=37693cfc748049e45d87b8c7d8b9aacd&amp;ID=2O0SD5ZOZ6PM78BWRNYBGNT5GUDYKPMEI3V2CSP11O NotFound
# NotFound
# NotFound
# None
# None
# http://lloydu-newpayee-authorised-online.com/ NotFound
# NotFound
# None
# None
#
# None
# None
# None
# None
# 40017 http://23.27.105.222 NotFound
# NotFound
# None
# None
# 40027 https://t.co/BeZkrsnEVP NotFound
# NotFound
# None
# None
# 40063 https://t.co/Z9ltxpLRpW40066 NotFound
# NotFound40067 40029 http://mariotessarollo.com/cp/cp.msi NotFound
# NotFound40068 https://t.co/9jkql4vIrC NotFound
# None
# None
#
# NotFound
# None
# 40062 https://t.co/KjiWsQTLRk NotFoundhttps://t.co/AnyrbtaN9f NotFound
# NotFound
# None
# None
#  https://t.co/ugnYlKrw0c NotFound40045 http://boatpecas.com.br NotFound
#
# NotFound
# NotFound
# None
# None
#
# NotFound
# None
# None
# None
# None
#
# None
# None
# None
# 40065 https://t.co/EUGeKV0UyT NotFound
# NotFound
# None
# None
# 40086 http://oii-italia.org/wordpress-5.7.zip NotFound
# NotFound
# None
# None
# 40120 http://www.daogetter.com/ NotFound
# NotFound
# None
# None
# 40145 http://marian.group NotFound
# NotFound
# None
# None
# 40124 http://paymentsnotifyalert.com/nationwide/IdentfyCustmer.php?/AccesManagement/IdentfyCustomer/OTPKIDCL7&amp;inID=zZpVGkAKOkWYUvhefYlyrXYmGzJLGbKUfJMUVQOlGqejyKUOosu NotFound
# NotFound
# None
# None
# 4015140130 40142 https://cve.mitre.org/news/archives/2021/news.html#March302021_NEC_Added_as_CVE_Numbering_Authority_CNA NotFound
# https://t.co/nFtfzYMM1X NotFound
# NotFound
#  http://britishgas-support.com NotFound
# None
# None
# 40156 http://www.massmediasondeoriente.com/wp-content/themes/jp-jp/home/cd8fe24027e0f5a77123a1d723d4fb11?cmd=_identifier_Demarrer_ID=4616310303185+_TIme:Mon,Mar,29,2021-11:56pmNotFoundNotFound
# None
# None
#  NotFound
# NotFound
# None
# None
#
# None
# None
# 40186 http://www.rakuten.co.jp.zep9i89hj9h5o2te8kqczsdl.shop/40157 http://www.massmediasondeoriente.com/wp-content/themes/jp-jp/home/cd8fe24027e0f5a77123a1d723d4fb11/?cmd=_identifier_Demarrer_ID=4616310303185+_TIme:Mon,Mar,29,2021-11:56pm NotFound
# NotFound NotFound
# NotFound
# None
# None
#
# None
# None
# 40214 http://rakutan-card.co.jp.tdgbfl.bar/e-navi01/members/settings/card-addition?token=aaaa@example.jp NotFound
# NotFound
# None
# None
# 40225 http://paddysitblog.xyz NotFound
# NotFound
# None
# None
# 4024040277 http://online-delete-device.net/ NotFound
# NotFound
# None
# None
# 40217 40287 https://t.co/uhHsTuQ6at NotFound
# NotFound
# None
# None
#  https://www.cc.uec.ac.jp/blogs/news/2021/03/20210330amazonphishing.html#2 NotFound
# NotFound
# None
# None
# http://tezpk.com NotFound
# NotFound
# None
# None
# 40292 http://hptatex.com/dolibarr/htdocs/core/js/lib_head.js.php?lang=en_US&amp;layout=classic&amp;version=13[.]0[.]2 NotFound
# NotFound
# None
# None
# 40248 http://account-amazon-com.7hcpcp.com/f21e255f89e0f258accbe4e984eef486/signin.php?country=JP-Japan&amp;lang=en NotFound
# NotFound
# None
# None
# 40293 http://guoshenlongjing.com/ NotFound
# NotFound
# None
# None
# 40295 http://204.44.99.238 NotFound
# NotFound
# None
# None
# 4031940318 http://koibecek.com/m/downloads/download.apk NotFound
# 4032540299 http://device-management-authentication.com/ NotFound
#  NotFound
# None
# None
#  http://aanddtraining.com/mazon/ NotFound
# NotFound
# http://hs-online-verifypaym.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=1679091c5a880faf6fb5e6087eb1b2dc&amp;ID=GB11188PP2MSJ1MTTH1WNKY9M576WADGFCHVPMQRTPUNone
# None
# 40311 http://en-order-amazon.com/ NotFound
# NotFound
# NoneNotFound
# None
# None
#
# None
# 40329 http://thechasebankof.com/login/  NotFound
# NotFound
# None
# NotFoundNone
#
# NotFound
# None
# None
# 40338 http://novcx.com/Material/office2019.zip NotFound
# 40352 http://page-contact-center016446.com NotFound
# NotFound
# None
# None
# NotFound
# None
# None
# 40332 http://hondaunlocker.com NotFound
# NotFound
# None
# None
# 40385 http://usercancellation.com/__MACOSX/hsbc/ NotFound
# NotFound
# None
# None
# 40359 http://m-page-realtor.com/ NotFound
# NotFound
# None
# None
# 4038040408 http://20200907234120.lamworld.co.bw/ NotFound
# NotFound
# None
# None
#  http://reviewonlinerequest.com/hsbc/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=7cbbc409ec990f19c78c75bd1e06f215&amp;ID=Z08LOTBTLG3X54EQOIPYM5QMJLRIBVE99P2DQETTWLCINNZ419F2A1S4J NotFound
# NotFound
# None
# None
# 40410 http://169.255.80.90 NotFound
# NotFound
# None
# None
# 40376 http://secured-device-cancellation.com/ NotFound
# NotFound
# None
# None
# 40445 http://notyou-proceed.com/ NotFound
# NotFound40390 http://fb84956-real-estate-item32895-page66783.house NotFound
# NotFound
# None
# None
# 40421 http://reviewshsbonline.com/ NotFound
# NotFound
# None
# None
#
# None
# None
# 40455 http://bankingwithsecurity.com/HALI_LIVE%202%202.zip NotFound
# NotFound
# None
# None
# 40467 http://donkeyvpn.com NotFound
# NotFound40477
# None
# None
#  http://paymentcheckednotice.com/hsbc/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=17e62166fc8586dfa4d1bc0e1742c08b&amp;ID=6ZHQUX6TNBBF7YNUMBUZLBXK23WK2MA07FWFJB6R6ZEMTS1HCC8EKVFDS9 NotFound
# NotFound
# None
# None
# 40422 http://mobilemovel.online/ NotFound
# NotFound
# None
# None
# 40499 https://threatpost.com/hades-ransomware-connections-hafnium/165069/ NotFound
# NotFound
# None
# None
# 40481 40500 http://page8929385fbk.com/ NotFound
# NotFoundhttp://verify-secureiproceed.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=03afdbd66e7929b125f8597834fa83a4&amp;ID=WN8SOS6VFQSYRDOT52I0Z54FM5EXZ8O5MKZXDP4HQR NotFound
#
# NotFound
# None40502 https://cve.mitre.org/news/archives/2021/news.html#March302021_Synopsys_Added_as_CVE_Numbering_Authority_CNA NotFound
# NotFound
# 40483 http://online-unauthorised-payee.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=9bf31c7ff062936a96d3c8bd1f8f2ff3&amp;ID=SV2HPWUBHZ4STCOHHPQMFSIG1X8PHQXJQOPIESMOZ2KOVZA1L NotFound
# NotFound
# NoneNone
# None
#
# None
#
# None
# None
# None
# 40510 http://qwfedy.com/MaterialChange/office2019.zip NotFound
# NotFound
# None
# None
# 40520 http://aaajosephctr.com/Roxwell%20Redirect.zip NotFound
# NotFound
# None
# None
# 40522 http://teamdd1.com/supporteerd/amazkn/mazon/ NotFound
# NotFound40518 http://lloydbanking-payeehelp.com/ NotFound
#
# NotFound
# None
# None
# None
# None
# 40374 http://security-hs-payeeonline-support.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=f457c545a9ded88f18ecee47145a72c0&amp;ID=E4GTVM42PSGQ2TU64D7X5LSERGXNV6J2JNTWGU1ARSSIXXOR NotFound
# 40553 http://162.241.201.243 NotFound40551 http://listingfun.com/
# NotFound
# NotFound
# None
# None
# NotFound
# None
# None
# NotFound
# None
# None
# 40542 http://vl789.com NotFound
# NotFound
# None
# None
# 40558 http://officc365.com40556 http://xuckduckgo.com NotFound
# NotFound NotFound
#
# NotFound
# None
# None
# None
# None
# 40606 http://protommaii.com NotFound
# NotFound
# None
# None
# 40607 http://fulfillmentcentersdeptstores.com/ NotFound
# NotFound
# None
# None
# 406144069440615 http://eeonline-change.com/ NotFound
# NotFound http://instawgram.com NotFound
# NotFound
#  http://198.46.93.168 NotFound
# NotFound
# None
# None
# None
# None
#
# None
# None
# 40757 http://efsystem.co.uk/assets/apps/remote-help.exe NotFound
# NotFound
# None
# None
# 40770 http://c4-amazon.work/ NotFound
# NotFound
# None
# None
# 40772 http://34.76.61.215 NotFound
# NotFound
# 40775 http://payee-confirmation-devices.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=c20ad4d76fe97759aa27a0c99bff6710&amp;ID=789ID6H2SVINICKHRTIQBS1FSEO4NA54R9VSRTXG277AV NotFound
# None
# NotFound
# None
# None
# None
# 40782 http://fnx278-disabled.com/ NotFound
# 40799 http://auth-personal-hsb.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=c20ad4d76fe97759aa27a0c99bff6710&amp;ID=SFPPESOQ8RNH0643MNNL6NBN17AV24F3ZT3TVS5K28 NotFound
# NotFoundNotFound
# None
# None
#
# None
# None
# 40816 http://ins6tagram.com40781 http://alertpayeereversal.com/hsbc/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=45c48cce2e2d7fbdea1afc51c7c6ad26&amp;ID=OFC51IVNN42BO4T2TJROXVEFQCHK5OWBH1GIXPAFLR0CLSB841HPKG3B4GBA NotFound NotFound
# NotFound
# None
# None
#
# NotFound
# None
# None
# 40805 http://standingorder-cancellation.com/hsbc/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=6c8349cc7260ae62e3b1396831a8398f&amp;ID=DWUTWWN9Q1GM1ALRYA14W6YL6JLI0T463ZSNCRBY26JNTX5W9OE5WW34LQ2 NotFound4082940817 http://auth-office365.com NotFound
# NotFound
# None
# None
#  http://benficiary-comfirmation.com/ NotFound
#
# NotFound
# None
# None
# NotFound
# None
# None
# 40824 http://leatherdrs.com NotFound
# NotFound
# None
# None
# 40833 http://mobile-attempt-billing-payment.com/ NotFound
# NotFound
# None
# None
# 40849 http://terms8436837fbk.com/ NotFound
# NotFound
# None
# None
# 40856 http://payee-confirmation-devices.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=182be0c5cdcd5072bb1864cdee4d3d6e&amp;ID=NKJAGOPMQ4THG8U9RS5BL9PREAMY442UL339ZRDFJL0WZ0BTWAJJI3RQ 40831 https://www.infosecurity-magazine.com:443/news/irs-warns-of-higher-education/ NotFound
# NotFound
# NoneNotFound
# NotFound
# None
# None
#
# None
# 40845 http://myyx128.com NotFound
# NotFound
# None
# None
# 40874 http://amandasilva83976414.link/ NotFound
# NotFound
# None
# None
# 40854 http://198a.cloud/down/app.apk NotFound
# NotFound
# None
# None
# 40855 http://themessage.club NotFound
# 40858 http://amzappslinks.biz NotFound
# NotFound
# NotFound
# None
# None
# 40891None
# None
#  http://162.0.215.253 NotFound
# NotFound
# 40893 http://o2-resolution.org/ None
# None
# NotFound40905 http://o2-verify-billing.info/ NotFound
#
# NotFound
# None
# None
# 40925 https://www.thegctf.org/Portals/1/Documents/Framework%20Documents/2020/GCTF%20Memorandum%20on%20Good%20Practices%20on%20Strengthening%20NLC%20in%20PCVE.pdf?ver=2020-09-29-100315-357 NotFound
# NotFound
# None
# None
# NotFound
# None
# None
# 40943 http://kaiabbey.space/FeanorBirmans.zip NotFound
# NotFound40932
# None
# None
#  http://5.206.227.228/zero;sh NotFound
# NotFound
# None
# None
# 40961 http://netflix-confirm.com NotFound
# NotFound
# None
# None
# 40991 http://webskypro4.space/wordpress-5.7.zip 40980 http://www.tube8.com/ NotFound
# NotFound
# None
# None
# NotFound
# NotFound
# None
# None
# 40997 http://messangaret.xyz NotFound
# NotFound
# None
# None
# 4101441002 http://billing-authentication.live/paypal/do.php?cmd=access&amp;idx=63787447 NotFound
# 41015 http://betsesportes.website NotFound
#  http://rabo-applicatie.cc/rb/?id=amazon[.]com%2FDefinitive-Collection-Don-Williams%2Fdp%2FB0002B166O NotFound
# NotFound
# NoneNotFound
# NotFound41020 http://paxful.credit/ NotFound
#
#
# None
# None
# None
# None
# None
# NotFound
# None
# None
# 41032 http://02securebilling.com/ NotFound
# NotFound
# None
# None
# 41046 http://aibpayeenewservice.com/Alert.php NotFound
# NotFound
# None
# None
# 41048 http://alboustane-mali.com/gestion/core/js/lib_head.js.php?lang=fr_FR&amp;layout=classic&amp;version=13[.]0[.]2 NotFound
# NotFound
# None
# None
# 4106341065  http://hs-payment-alerts.com/login/login.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=6f4922f45568161a8cdf4ad2299f6d23&amp;ID=VIN9E5UO4XYR7A0FDH6YPZB2I2KW9G3GRXE442GT9T7O8TG27X NotFound
# NotFound
# None
# Nonehttp://hdbfhjbs.com/fghjk/ NotFound
# NotFound
#
# None
# None
# 41044 http://archive.org NotFound
# NotFound
# 41070 http://hisotrycheseengjkkl.com NotFound
# NotFound
# None
# None
# None
# None
# 41088 http://secure-hs-payee-removalgroup.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=67c6a1e7ce56d3d6fa748ab6d9af3fd7&amp;ID=RCCUQ08LWTRJYGY5777Z6MMULN9Q0J85EA881LF3PGJ1HQR14NQS71T7ULUF NotFound
# NotFound
# None
# None
# 41082 http://paperble6ty.com/ NotFound
# NotFound
# 4109041061  http://confirmation-commandes.com/ NotFoundhttp://secure-online-remove.com/
#  NoneNotFound
# NotFound
# None
#
# None
# None
# NotFound
# None
# None
# 41114 http://security-hs-payee-support-alert.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=68d30a9594728bc39aa24be94b319d21&amp;ID=BI197ESO07CJNTIEDSKQGC4O0K8QXTEURRG6E6VPME2QXDKUDL5HHDWNRVVX7 NotFound
# NotFound
# None
# None
# 41123 http://plcsystemsupport.com/ NotFound
# NotFound
# None
# None
# 41091 http://view-drivers-license-uk.com/ NotFound41128 http://auth-5i.com
#  NotFound
# NotFound
# None
# None
# 41132 NotFound
# None
# None
# http://shoutexas.online/nrjpfx01-bcgshey-gx5f4s4-ere5re84-xc45xfs6-er5e8re84-xvxc598a-re8r7e8-cvc58vd/edgjpx01.zip41137 https://tryhackme.com/room/0day NotFound
#  NotFound
# NotFound
# None
# None
# 41192 http://tyanrmak.com/ NotFound
# NotFound
# None
# None
# NotFound
# None
# 41168 http://ioabc.wif.com.br/ NotFound
# NoneNotFound
# None
# None
#
# 41194 http://192.185.165.90 NotFound
# NotFound
# None
# None
# 4120341201 http://security-hs-device.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=34173cb38f07f89ddbebc2ac9128303f&amp;ID=3JDSSLPPFH8F5P4WA8J9YVFFPC4NY4EVDHY8PNXCS NotFound
# NotFound
#  http://tomyumgoong.site NotFound
# NotFound
# ...
# 48574
# NotFound
# Nonehttps://t.co/JZiXj3AbuI NotFound
# None
#
# NotFound
# NotFound
# None
# None
# None
# None
# NotFound48581
# None
# None
# 48579 http://seeyouamazon.foramazonmore.shop/signin/?openid.pape.max_auth_age=0&amp;openid.return_to=https%3A%2F%2Fwww.amazon.co.jp%2F%3Fref_%3Dnav_em_hd_re_signin&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select NotFoundhttp://amozon.co.jp.4jape1n5.co/?token=AMzM0MDMwbXBHV0tK NotFound
# NotFound
# None
# None
#
# NotFound
# None
# None
# 48645 http://abuseipdb.com/check/104.196.116.149 NotFound
# NotFound
# None
# None
# 48641 http://abuseipdb.com/check/34.74.152.1 NotFound
# NotFound
# None
# None
# 4859548588 http://banma.freeps3.com/signin/?openid_pape_max_auth_age=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0 NotFound
# NotFound
# None
# None
#  http://updatetosave.foramazoncardmore.monster/signin/?openid.pape.max_auth_age=0&amp;openid.return_to=https%3A%2F%2Fwww.amazon.co.jp%2F%3Fref_%3Dnav_em_hd_re_signin&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0 NotFound
# 48618 http://updateiediately.foramazoncardmore.buzz/signin/?openid.pape.max_auth_age=0&amp;openid.return_to=https%3A%2F%2Fwww.amazon.co.jp%2F%3Fref_%3Dnav_em_hd_re_signin&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0 NotFound
# NotFound
# None
# None
# 48643 http://abuseipdb.com/check/34.75.61.226 NotFound
# NotFound
# None
# None
# NotFound
# None
# None
# 48654 http://abuseipdb.com/check/207.45.183.66 NotFound
# NotFound
# None
# None
# 48647 http://abuseipdb.com/check/34.75.68.48 NotFound
# NotFound
# None
# None
# 48651 http://abuseipdb.com/check/34.73.165.13 NotFound
# NotFound48692 http://camepahurite.com NotFound
# NotFound
# None
# None
# 48703 http://page-contact-center85412006.com NotFound
# NotFound
# None
# None
# None
#
# None
# 48649 http://abuseipdb.com/check/34.73.61.171 NotFound
# NotFound
# None
# None
# 48710 http://anataban.com/ANATABAN-SITE-FILES.zip NotFound
# NotFound
# None
# None
# 48712 http://css-cj0kcqjwpdq.info/ NotFound
# NotFound
# None
# None
# 4872248738 http://secured-hs-bc-payee-online-support.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=a1d0c6e83f027327d8461063f4ac58a6&amp;ID=XP795S74K3YMJZSCND43MGQV3V6YIBUFNXOWIM4ZZ2PG5DPNI3YTFT7KNKLC2 NotFound
# NotFound
# None
# None
#  http://hs-online-transactions.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=54229abfcfa5649e7003b83dd4755294&amp;ID=CC1TAM5O458SCFTHNNAJ23B21G8ZJCNJV60BEF6K30W1DLU6OKB0EOW NotFound
# NotFound
# None
# None48741 http://loadinggotoomanage24.com NotFound
#
# NotFound48737 http://secured-hs-bc-payee-support.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=19ca14e7ea6328a42e0eb13d585e4c22&amp;ID=L2T0Q2I6U3F7CT2OQZG67OERRBCFBI93LQUNG8JDTWCTXTEX0O NotFound
# NotFound
# None
# None
#
# None
# None
# 48777 http://melaniewalter5324856.link/ NotFound
# NotFound
# None
# None
# 48746 http://securehspayee.com/Login.php NotFound
# NotFound
# None
# None
# 48814 http://verify-hs-onlinepayment.com/hsbc/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=f457c545a9ded88f18ecee47145a72c0&amp;ID=J08JN42LT328IME91L4RAFFU4684GGUYNEV7MHTNVHII NotFound
# NotFound
# None
# None48806 http://onlinebanking-personal-log-on.com/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=c20ad4d76fe97759aa27a0c99bff6710&amp;ID=IRTE6GIDT58D82C8HG1MX1QQ96QJW0SNWHPVWHID4SWIO NotFound
# NotFound
# None48796 http://savelatoresapum.com NotFound
# NotFound
# None
# None
#
# None
#
# 48801 http://verify-hs-onlinepayment.com/hsbc/idv.Log.php?ud=dashbrd&amp;idv[.]cmd=LOGIN&amp;accessU=c9f0f895fb98ab9159f51fd0297e236d&amp;ID=ULA9DRQJ9S0J5JA6YS30SXEG3OWXJNCV3C679XHWXKE7T NotFound
# NotFound
# None
# None
# 48868 http://elmangrupgsm.com NotFound48865 http://abuseipdb.com/check/35.183.60.188
# NotFound
# None
# None
#  NotFound
# NotFound
# None
# None
# 4884748899 http://www.postepaynuovo.com/jod-fcc/fcc-authenticazione.php NotFound
# NotFound
# None
#  http://mone65636.work/ NotFound
# NotFound
# None
# None
# 48855 https://pastebin.com/raw/1sYgCyLV NotFound
# NotFound
# None
# None
# None48953 http://2d1005fd96.nxcli.net/ NotFound
# NotFound
#
# None
# None
# 48960 http://woodlandrp.info/wp-login.php?loginSocial=amazon NotFound
# NotFound48955 http://103.224.90.118
# NotFound
# NotFound
# None
# None
# 49005 https://t.co/YCaEkn9FQD NotFound
# NotFound
# None
# None
# None
# None
# 48983 http://www.jp-cr-mufg.xyz/48979 https://t.co/L7lTfqCrff  NotFound
# NotFound
# None
# None
# NotFound
# NotFound
# None
# None
# 48976 https://t.co/RngYd5ovLg NotFound
# NotFound
# None
# None
# 4904749014 https://t.co/2E8rOG7U9t http://www.raikuten.co.jp.hya6uwnn.cc/jp/rms/index.php?openid.pape.max_auth_age=0&amp;openid.return_to=https%3A%2F%2Fwww.rakuten.co.jp%2F%3F_encoding%3DUTF8%26ref_%3Dnavm_em_hd_re_signin&amp;openid.identity=http%3A%2F NotFound
# NotFound
# None
# None
#  NotFound
# NotFound
# None
# None
# 49058 https://www.cc.uec.ac.jp/blogs/news/2021/04/20210417amazonphishing.html#3 NotFound
# NotFound
# None
# None
# 49065 http://changeinformation.theamazonyear.xyz/signin/?openid.pape.max_auth_age=0&amp;openid.return_to=https%3A%2F%2Fwww.amazon.co.jp%2F%3Fref_%3Dnav_em_hd_re_signin&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select NotFound
# NotFound
# None
# None
# 49028 http://www.myetherwaller.ink/#/access-my-wallet NotFound
# NotFound
# None
# None
# 49060 https://t.co/1P23ruzld7 NotFound
# NotFound
# None
# None
# 49075 http://chenk.azhong04184.gq/?user_token=aaaa@example.jp NotFound
# NotFound
# None
# None
# 49094 http://abouttheupdate.theamazonyear.club/signin/?openid.pape.max_auth_age=0&amp;openid.return_to=https%3A%2F%2Fwww.amazon.co.jp%2F%3Fref_%3Dnav_em_hd_re_signin&amp;openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select NotFound49098 http://amozon.co.jp.bufanglnln188.xyz/ap/signin.php?openid.pape.max_auth_age=0&amp;openid.return_to=%1eb16363837f6d9107f291245d3b342ba2ebe865 NotFound
# NotFound
# None
# None
#
# NotFound
# None
# None
# 49101 http://anazon.co.jp.basccdc.buzz/?token=CNDgzNTY3cjM3eEp0 NotFound
# NotFound
# None
# None
# 49127 http://jivikacctv.com NotFound
# NotFound
# None
# None49136 http://abuseipdb.com/check/13.124.222.242 NotFound
# NotFound
# None
#
# None
# 49149 http://www.snbc-card.we0t.com/confirm/landing.html NotFound
# NotFound
# None
# None
# 49217 49212 http://betpro.spacehttp://360bahis94.com NotFound
# NotFound
#  NotFoundNone
# None
#
# NotFound
# None
# None
# 49219 http://myaccounts-barcs.com/ NotFound
# NotFound
# None
# None
# 49229 http://killoribottie.com NotFound
# NotFound
# None
# None
# 49222 http://rpxos.com/Chase/XBALTI%20V5/ NotFound
# NotFound
# None
# None
# 49253 http://chase-securityb04.com NotFound
# NotFound
# None
# None
# 49276 http://officedirectory.link/data/ NotFound
# NotFound
# None
# None
# 4925049228 http://acsqq.com/Chase/secure/ NotFound
# NotFound
# None
# None
#  http://360bahis91.com NotFound
# NotFound
# None
# None
# 49283 https://crt.sh/?id=4390423758 NotFound
# NotFound
# None
# None
# 49287 http://loadingpageppyl214.com NotFound
# NotFound
# None
# None
# 49346 49308 http://360bahis95.com NotFound
# NotFound
# None
# http://jp-mvf.com/ap.alret.signin.amazon.co/ NotFound
# NotFound
# None
# None
# 49318 http://sqrevlsrv.com/h8y/gr0ups3/wax8i/times/t0fll2.zipNone
#  NotFound
# NotFound
# None
# None
# 49347 http://shannonspersonnel.com/ NotFound
# 49349 http://208.77.216.21 NotFound
# NotFound
# None
# None
# NotFound
# None
# None
# 49384 http://Itau..com.br NotFound
# 49383 NotFound
# None
# None
# http://meu.appitauitoken..com NotFound
# NotFound
# 49371 None
# None
# https://t.co/nBZoVYxwAZ NotFound
# NotFound
# None
# 49435 http://saudiwallcovering.com//wp-content/themes/log/jp/9a3bec7b4867d2127e4c83e271916053?cmd=_identifier_Demarrer_ID=6488787474432+_TIme:Sun,Apr,18,2021-12:24amNone
# 49387 http://185.27.134.113 NotFound
# NotFound
# None
# None
#  NotFound
# NotFound
# None
# None
# 49436 http://saudiwallcovering.com/wp-content/themes/log/jp/9a3bec7b4867d2127e4c83e271916053/?cmd=_identifier_Demarrer_ID=6488787474432+_TIme:Sun,Apr,18,2021-12:24am NotFound
# NotFound49447 http://direct.smbc.co.jp.lowchost.info/SMBC/ NotFound
#
# None
# None
# NotFound
# None
# None
# 49529 http://lcmclpcclplzzlmlzpl.net/www.labanquepostale.fr/ NotFound
# NotFound
# None
# None
# 49539 http://s-connect-lbp.live/ NotFound
# NotFound
# None
# None
# 49526 http://atgcom.net NotFound
# NotFound
# None
# None
# 49557 http://gatoearn.com/tokenlite.zip NotFound
# NotFound
# None
# None
# 49554 http://lcmclpcclplzmzmlzz.com/ NotFound
# NotFound
# None
# None
# 49571 http://abuseipdb.com/check/51.178.182.70 NotFound
# NotFound
# None
# None
# 4958149570 http://home-server-sicur.com/ NotFound
# NotFound http://puzz3lz.com NotFound
# NotFound
# None
# None
#
# None
# None
# 49584 http://n3pil.com NotFound
# NotFound
# None
# 49590 http://page-support-center907632.com NotFound
# 49586 http://user8m.comNotFound
#  NotFound
# NotFound
# None
# None
# None
# None
# None
# 49604 http://w3n7t.com NotFound
# NotFound
# None49611 http://z1an4.com
# NoneNotFound
# NotFound
# None
# None
#
# 49642 http://page-support-center9521026.com NotFound
# NotFound
# None
# None
# 49710 http://www.samnetakademi.com.tr/admin/wellsfargo/login.php NotFound
# NotFound
# None
# None
# 49613 http://bullsignals.net 49718 http://47.88.106.85 NotFound
# NotFound
# None
# None
# NotFound
# NotFound
# None
# None
# 49747 http://functionality-billrequirements.com/wso.php NotFound
# NotFound
# None
# None
# 49751 http://byuanking.com/filed/amaz%20(1).zip NotFound
# NotFound
# None
# None
# 49752 http://byuanking.com/filed/mazon/ NotFound
# NotFound
# None
# None
# 49815 http://rvcj8xc616holdings.buzz/p19j/customer1.exe NotFound
# NotFound
# None
# None
# 49852 https://www.thehexninja.com/2021/04/getting-hashes-to-virus-total-from.html?m=1 NotFound
# NotFound
# None
# None
# 49908 http://kingteb.com NotFound
# NotFound
# None
# None
# 49830 https://crt.sh/?id=4395103378 NotFound
# NotFound
# None
# None
# 49295 http://lcmclpcclplzmzmlzmzpz.com/www.labanquepostale.fr/ NotFound
# NotFound
# None
# None
# 49944 http://parclbackup.com/FEE.zip NotFound
# NotFound
# None
# None
# 49967 http://togelwd.org NotFound
# NotFound
# None
# None
# 49940 http://jessicaanderson1777653949.link/ NotFound
# NotFound
# None
# None
# 49974 http://orange-service1201.moonfruit.com/ NotFound
# NotFound
# None
# None
# 49979 http://qr0tmic.com/secure3b/chase/ NotFound
# NotFound
# None
# None
# 49992 http://tiptop4d.live NotFound
# NotFound
# None
# None
# 49982 http://steamcommunityl.com NotFound
# NotFound
# None
# None
# 49636 http://pypl.support NotFound
# NotFound
# None
# None
# 46772 http://amazon.co.nhef.cn/login.php NotFound
# NotFound
# None
# None
# 49915 https://malwaredevil.com/2021/04/19/hunting-phishing-websites-with-favicon-hashes-mon-apr-19th/?utm_campaign=twitter&utm_medium=twitter&utm_source=twitter NotFound
# NotFound
# None
# None
# 47072 http://wajloq.com/Chase/secure3a/ NotFound
# NotFound
# None
# None
# 48075 http://morlaas.ovh NotFound
# NotFound
# None
# None
# 31830 http://win1009.com NotFound
# NotFound
# None
# None
#                       tweet_date        account  ioc_type  \
# 0                     tweet_date        account  ioc_type
# 1      2021-01-01 00:09:03+00:00  MalwarePatrol       url
# 2      2021-01-01 00:09:03+00:00  MalwarePatrol       url
# 3      2021-01-01 00:09:03+00:00  MalwarePatrol    domain
# 4      2021-01-01 00:09:03+00:00  MalwarePatrol    domain
# ...                          ...            ...       ...
# 89094  2021-07-31 21:01:16+00:00  ShoestringSoc        ip
# 89095  2021-07-31 21:19:38+00:00       ecarlesi       url
# 89096  2021-07-31 21:25:08+00:00       ecarlesi       url
# 89097  2021-07-31 22:56:45+00:00    phishunt_io        ip
# 89098  2021-07-31 22:56:45+00:00    phishunt_io    domain
#
#                                                ioc_value  type_of_attack  \
# 0                                              ioc_value  type_of_attack
# 1                               http://dubioustimes.com/    ['phishing']
# 2                                https://t.co/m4mjDMt7az    ['phishing']
# 3                                       dubioustimes.com    ['phishing']
# 4                                                   t.co    ['phishing']
# ...                                                  ...             ...
# 89094                                     197.156.73.150    ['honeypot']
# 89095  http://xmyparcel21-redelivery.com/postoffice/fee/    ['phishing']
# 89096           http://igbusiness-form.com/283772919101/    ['phishing']
# 89097                                      217.160.0.240    ['phishing']
# 89098                            bankofamerica-miami.com    ['phishing']
#
#                     tweet_url  \
# 0                   tweet_url
# 1      1.3447977507481887e+18
# 2      1.3447977507481887e+18
# 3      1.3447977507481887e+18
# 4      1.3447977507481887e+18
# ...                       ...
# 89094  1.4215767218080522e+18
# 89095  1.4215813444679803e+18
# 89096   1.421582728231678e+18
# 89097   1.421605783297413e+18
# 89098   1.421605783297413e+18
#
#                                                     text     status  \
# 0                                                   text     status
# 1      Another active #Phishing targeting Google Driv...      Clean
# 2      Another active #Phishing targeting Google Driv...      Clean
# 3      Another active #Phishing targeting Google Driv...      Clean
# 4      Another active #Phishing targeting Google Driv...      Clean
# ...                                                  ...        ...
# 89094  New attacker reported:\n\nIP:   197.156.73.150...      Clean
# 89095  Threat on hxxps://xmyparcel21-redelivery[.]com...      Clean
# 89096  Threat on hxxps://igbusiness-form[.]com/283772...      Clean
# 89097  #NewPhishing | #phishing #scam\n\n🌐 /bankofame...  Malicious
# 89098  #NewPhishing | #phishing #scam\n\n🌐 /bankofame...      Clean
#
#        pulse_count  score  alert_length  \
# 0      pulse_count  score  alert_length
# 1              NaN    NaN           0.0
# 2              NaN    NaN           0.0
# 3              NaN    NaN           0.0
# 4              NaN    NaN           0.0
# ...            ...    ...           ...
# 89094          NaN    NaN           0.0
# 89095          NaN    NaN           0.0
# 89096          NaN    NaN           0.0
# 89097          NaN    NaN           3.0
# 89098          NaN    NaN           0.0
#
#                                                   alerts  cve  \
# 0                                                 alerts  cve
# 1                                                    NaN  NaN
# 2                                                    NaN  NaN
# 3                                                    NaN  NaN
# 4                                                    NaN  NaN
# ...                                                  ...  ...
# 89094                                                NaN  NaN
# 89095                                                NaN  NaN
# 89096                                                NaN  NaN
# 89097  Unix.Malware.Agent-7147430-0, ELF:Agent-VW\ [T...  NaN
# 89098                                                NaN  NaN
#
#        first_submission_date  first_submission  first_submission_diff  \
# 0      first_submission_date  first_submission  first_submission_diff
# 1                        NaN               NaN                    NaN
# 2                        NaN               NaN                    NaN
# 3                        NaN               NaN                    NaN
# 4                        NaN               NaN                    NaN
# ...                      ...               ...                    ...
# 89094                    NaN               NaN                    NaN
# 89095                    NaN               NaN                    NaN
# 89096                    NaN               NaN                    NaN
# 89097                    NaN               NaN                    NaN
# 89098                    NaN               NaN                    NaN
#
#        first_submission_diff_sec
# 0      first_submission_diff_sec
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 89094                        NaN
# 89095                        NaN
# 89096                        NaN
# 89097                        NaN
# 89098                        NaN
#
# [89099 rows x 17 columns]
#
# Time :  91.63

# %%
# To read saved local copy of database
df = pd.read_csv('/content/drive/MyDrive/TIP/AV/Final_AV_Output_20_7_2022.csv',names=fields_name, encoding='utf-8',engine='python')

# %%
df=df[2:]

# %%
df['status'].value_counts()
# Out:
# Clean         73392
# NotFound      10382
# Malicious      6055
# RetryError     1809
# Name: status, dtype: int64

# %%
df.to_csv('/content/drive/MyDrive/TIP/AV/Final_AV_Output_20_7_2022.csv', index=False)

# %%
def report(index):

    ioc = df.loc[index, 'ioc']

    ioc_type = df.loc[index, 'ioc_type']
    if (ioc_type=='url'):
     if(df.loc[index, 'status']=='Malicious'):
       if((df.loc[index, 'alert_length'] == 0) or (df.loc[index, 'alert_length'] is None)):
          df.loc[index, 'status'] = 'Clean'
          df.loc[index, 'pulse_count'] = None
          df.loc[index, 'score'] = None
          df.loc[index, 'alert_length'] = None
          df.loc[index, 'alerts'] = None
          df.loc[index, 'cve'] = None
          df.loc[index, 'first_submission_date'] = None
          df.loc[index, 'first_submission'] = None
          df.loc[index, 'first_submission_diff'] = None
          df.loc[index, 'first_submission_diff_sec'] = None
    print(index, ioc, df.loc[index, 'status'])
    return

start =1
end = 65000

#AlienVault.API_KEY = '4a7ae91cad86f294815870767e89739ec1428fdc516d51bca148468bdbfe05e4'

indices = list(range(start,end))

try:
    with ThreadPoolExecutor(max_workers=50) as executor:

        executor.map(report, indices)

        executor.shutdown(wait=True)

except Exception as e:
    print(e)

#print(df)

df.to_csv('/content/drive/MyDrive/av/AlienVault_Output_Final_Jan_March_2022.csv', na_rep='', index=None)

end_time = time.time()

print(f'\nTime : {end_time - start_time : .2f}')

# %%
df = pd.read_csv('/content/drive/MyDrive/av/AlienVault_Output_Final_Jan_March_2022.csv', names=['t_time', 'account', 'ioc_type', 'ioc', 'attack_type', 't_url', 'status', 'pulse_count', 'score',
                 'alert_length', 'alerts', 'cve', 'first_submission_date', 'first_submission', 'first_submission_diff', 'first_submission_diff_sec'])
N = 15
new_df = df.iloc[N: , :]
new_df.to_csv('/content/drive/MyDrive/av/AlienVault_Output_Final_Jan_March_2022.csv', na_rep='', index=None)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (7,8,9,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
first_submission_date='2019-09-05 08:59:29'	
source_date='2021-07-29 13:35:02+00:00'
date_format=r'%Y-%m-%d %H:%M:%S'
source_date= source_date[:19]

# %%
source_date
# Out:
# datetime.datetime(2021, 7, 29, 13, 35, 2)

# %%
if source_date < first_submission_date:
            print("Twitter")
            duration = first_submission_date - source_date
            print(duration)
else:
  print("TIP")
  duration = first_submission_date - source_date
  print(duration)
